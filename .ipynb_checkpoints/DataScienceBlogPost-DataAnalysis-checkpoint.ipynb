# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_goodread_df = pd.read_csv('corrected_goodread_df.csv', error_bad_lines = False)
original_goodread_df.head()
# Out:
#    bookID                                              title        author  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...  J.K. Rowling
# 1       2  Harry Potter and the Order of the Phoenix (Har...  J.K. Rowling
# 2       4  Harry Potter and the Chamber of Secrets (Harry...  J.K. Rowling
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...  J.K. Rowling
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...  J.K. Rowling
#
#    average_rating        isbn        isbn13 language_code  num_pages  \
# 0            4.57   439785960  9.780440e+12           eng        652
# 1            4.49   439358078  9.780439e+12           eng        870
# 2            4.42   439554896  9.780440e+12           eng        352
# 3            4.56  043965548X  9.780440e+12           eng        435
# 4            4.78   439682584  9.780440e+12           eng       2690
#
#    audio_hrs  ratings_count  text_reviews_count     publication_date  \
# 0        0.0        2095690               27591  2006-09-16 00:00:00
# 1        0.0        2153167               29221  2004-09-01 00:00:00
# 2        0.0           6333                 244  2003-11-01 00:00:00
# 3        0.0        2339585               36325  2004-05-01 00:00:00
# 4        0.0          41428                 164  2004-09-13 00:00:00
#
#          publisher  series
# 0  Scholastic Inc.    True
# 1  Scholastic Inc.    True
# 2       Scholastic    True
# 3  Scholastic Inc.    True
# 4       Scholastic    True

# %%
goodread_df = original_goodread_df.copy()

# %%
goodread_df.dtypes
# Out:
# bookID                  int64
# title                  object
# author                 object
# average_rating        float64
# isbn                   object
# isbn13                float64
# language_code          object
# num_pages               int64
# audio_hrs             float64
# ratings_count           int64
# text_reviews_count      int64
# publication_date       object
# publisher              object
# series                   bool
# dtype: object

# %%
#create copy of df to fix datatypes
goodread_copy_df = goodread_df.copy()
goodread_copy_df.head()

#drop unneeded rows: bookID, isbn, isbn13, num_pages, audio_hrs, publisher
goodread_copy_df = goodread_copy_df.drop(columns=['bookID', 'isbn', 'isbn13', 'num_pages', 'audio_hrs', 'publisher'])

#update publication_date to datetime
goodread_copy_df['publication_date'] = pd.to_datetime(goodread_copy_df['publication_date'])
  
goodread_copy_df.dtypes
# Out:
# title                         object
# author                        object
# average_rating               float64
# language_code                 object
# ratings_count                  int64
# text_reviews_count             int64
# publication_date      datetime64[ns]
# series                          bool
# dtype: object

# %%
print(len(goodread_copy_df))
# Out:
# 10539

# %%
#check titles
titles_sum = goodread_copy_df.title.value_counts()
print(titles_sum.head(460))
# Out:
# The Iliad                                   9
# The Brothers Karamazov                      9
# The Odyssey                                 8
# Anna Karenina                               8
# Gulliver's Travels                          8
#                                            ..
# Far From the Madding Crowd                  2
# Timequake                                   2
# The Gospel According to Jesus Christ        2
# The Little Friend                           2
# Body Language (Mark Manning Mystery  #3)    1
# Name: title, Length: 460, dtype: int64

# %%
#create a list of dupe books that need to be consolidated
titles = list(titles_sum.index.values)
titles = titles[:459]
titles
# Out:
# ['The Iliad',
#  'The Brothers Karamazov',
#  'The Odyssey',
#  'Anna Karenina',
#  "Gulliver's Travels",
#  "'Salem's Lot",
#  "A Midsummer Night's Dream",
#  'The Picture of Dorian Gray',
#  'Romeo and Juliet',
#  'Sense and Sensibility',
#  'The Secret Garden',
#  'Macbeth',
#  'The Scarlet Letter',
#  'The Great Gatsby',
#  'The Histories',
#  'Collected Stories',
#  'Robinson Crusoe',
#  'Treasure Island',
#  'Frankenstein',
#  "Charlotte's Web",
#  'Don Quixote',
#  'Jane Eyre',
#  'A Tale of Two Cities',
#  'War and Peace',
#  'Much Ado about Nothing',
#  'The House of Mirth',
#  'The Shining',
#  'The Communist Manifesto',
#  'The Idiot',
#  'One Hundred Years of Solitude',
#  'Dracula',
#  'Atlas Shrugged',
#  'Paradise Lost',
#  'Eugene Onegin',
#  'The Return of the King (The Lord of the Rings  #3)',
#  'The Enemy (Jack Reacher  #8)',
#  'Pride and Prejudice',
#  'Memoirs of a Geisha',
#  'King Lear',
#  'Julius Caesar',
#  'Howards End',
#  'The Decline and Fall of the Roman Empire',
#  'Open House',
#  'Critique of Pure Reason',
#  'Emma',
#  'Twelfth Night',
#  "The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)",
#  'Crime and Punishment',
#  "Man's Search for Meaning",
#  'The Da Vinci Code (Robert Langdon  #2)',
#  'Billy Budd  Sailor',
#  'Lolita',
#  'The Woman in White',
#  'Great Expectations',
#  'Selected Poems',
#  'The Complete Stories',
#  'The Invisible Man',
#  'Hamlet',
#  'Sula',
#  'Little Women',
#  'Mansfield Park',
#  'Tripwire (Jack Reacher  #3)',
#  'The Aeneid',
#  'The Known World',
#  'Les Misérables',
#  'White Teeth',
#  'The Complete Plays',
#  'The Lord of the Rings (The Lord of the Rings  #1-3)',
#  'Love',
#  'Othello',
#  'Far from the Madding Crowd',
#  'Starship Troopers',
#  'Angels & Demons (Robert Langdon  #1)',
#  "Alice's Adventures in Wonderland",
#  'John Adams',
#  'The Lovely Bones',
#  'The Call of the Wild',
#  'The Count of Monte Cristo',
#  'Moby Dick',
#  'Last Man Standing',
#  'The Complete Novels',
#  'Heart of Darkness',
#  'The Canterbury Tales',
#  'The Moonstone',
#  'Lysistrata',
#  'As You Like It',
#  'The Last Kingdom (The Saxon Stories  #1)',
#  'The Art of War',
#  'Selected Stories',
#  'Kim',
#  'Vanity Fair',
#  'The Epic of Gilgamesh',
#  'The Long Goodbye (Philip Marlowe  #6)',
#  'The Time Machine',
#  'The Poisonwood Bible',
#  'The Metamorphosis and Other Stories',
#  'A Portrait of the Artist as a Young Man',
#  'The Silmarillion',
#  'Blink: The Power of Thinking Without Thinking',
#  'The Divine Comedy',
#  'Magician: Apprentice (The Riftwar Saga  #1)',
#  'Dubliners',
#  'James and the Giant Peach',
#  'To Kill a Mockingbird',
#  'The Hound of the Baskervilles',
#  'Cyrano de Bergerac',
#  'Nicomachean Ethics',
#  'The Eternity Code (Artemis Fowl  #3)',
#  'The Mill on the Floss',
#  'On the Road',
#  'Cry  the Beloved Country',
#  'The Birth of Tragedy',
#  'The Sea',
#  'Lord of the Flies',
#  'Act of Treason (Mitch Rapp  #9)',
#  'The Subtle Knife (His Dark Materials  #2)',
#  'A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#  'Siddhartha',
#  'Persuasion',
#  "The Handmaid's Tale",
#  'Matilda',
#  'Oliver Twist',
#  'In Cold Blood',
#  'Moby-Dick',
#  'Never Let Me Go',
#  'The Curious Incident of the Dog in the Night-Time',
#  'Deception Point',
#  'Adventures of Huckleberry Finn',
#  'Haunted',
#  'The Origin of Species',
#  'King Richard II',
#  'The Book of Five Rings',
#  'A Little Princess',
#  'Doctor Faustus',
#  'The Metamorphosis',
#  "A Room of One's Own",
#  'The Silver Pigs (Marcus Didius Falco  #1)',
#  'Light in August',
#  'English Passengers',
#  'Democracy in America',
#  'Five Quarters of the Orange',
#  'The Echo Maker',
#  'Echo Park (Harry Bosch  #12; Harry Bosch Universe  #16)',
#  "Midnight's Children",
#  'Before Night Falls',
#  'Bargaining for Advantage: Negotiation Strategies for Reasonable People',
#  'Conversations with Bernard Malamud (Literary Conversations)',
#  "The Prime of Miss Jean Brodie / The Girls of Slender Means / The Driver's Seat / The Only Problem",
#  'Beloved',
#  "Girls' Night In",
#  'Five Patients',
#  'Mere Christianity',
#  'To the Lighthouse',
#  "My Sister's Keeper",
#  'The Damned (Vampire Huntress  #6)',
#  'The Locked Room (The New York Trilogy  #3)',
#  'The Illustrated A Brief History of Time',
#  'The Da Vinci Code',
#  'Casino Royale',
#  'The Short Stories',
#  'Them: Adventures with Extremists',
#  'The Republic',
#  'Nineteen Eighty-Four',
#  'Black Beauty',
#  'The Poet (Jack McEvoy  #1; Harry Bosch Universe  #5)',
#  'Philosophical Investigations',
#  'Love in the Time of Cholera',
#  'Danny the Champion of the World',
#  'Are We There Yet?',
#  'Monkey Business',
#  'How to Win Friends and Influence People',
#  "A Hard Day's Write: The Stories Behind Every Beatles Song",
#  'Rob Roy',
#  'Candide: or  Optimism',
#  'Sputnik Sweetheart',
#  'Swan Song',
#  'The Heart Is a Lonely Hunter',
#  'Slow Learner: Early Stories',
#  'Tara Road',
#  'Blackberry Wine',
#  'Fierce Invalids Home from Hot Climates',
#  'The Journals of Sylvia Plath',
#  'Foxmask (Saga of the Light Isles  #2)',
#  'The Best American Mystery Stories 2004',
#  'The Guardian',
#  'Around the World in Eighty Days',
#  'The Hunchback of Notre-Dame',
#  'Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)',
#  'Americana',
#  'Dry',
#  'Different Seasons',
#  'The Sea of Monsters (Percy Jackson and the Olympians  #2)',
#  'Blind Willow  Sleeping Woman',
#  'Tehanu (Earthsea Cycle  #4)',
#  'Pygmalion',
#  'The Autograph Man',
#  'Republic',
#  'Song of Solomon',
#  'The Castle of Otranto',
#  'Choke',
#  "The Botany of Desire: A Plant's-Eye View of the World",
#  'Icebound',
#  'An Instance of the Fingerpost',
#  "The Dirt: Confessions of the World's Most Notorious Rock Band",
#  'The Tale of Genji',
#  'While I Was Gone',
#  'Mysteries',
#  'The Gunslinger',
#  'Nimitz Class (Admiral Arnold Morgan  #1)',
#  'Trace (Kay Scarpetta  #13)',
#  'Babyville',
#  'Heat',
#  "Alice's Adventures in Wonderland & Through the Looking-Glass",
#  'White Oleander',
#  'The Second Sex',
#  'Message in a Bottle',
#  'The Adventures of Tom Sawyer (Adventures of Tom and Huck  #1)',
#  'Identity',
#  'The Major Works',
#  'Middlemarch',
#  'The Sun Also Rises',
#  'Murder on the Orient Express (Hercule Poirot  #10)',
#  'The Pact',
#  'To Sail Beyond the Sunset',
#  'Murder at the Vicarage (Miss Marple  #1)',
#  'The Damnation Game',
#  'In the Shadow of Young Girls in Flower (In Search of Lost Time  #2)',
#  'The Presocratic Philosophers',
#  'A Farewell to Arms',
#  'Phantoms',
#  'Bookends',
#  'Basket Case',
#  'The Stranger',
#  'Marie Antoinette: The Journey',
#  'The 9/11 Commission Report: Final Report of the National Commission on Terrorist Attacks Upon the United States',
#  'Faust  Part Two',
#  "The Bonesetter's Daughter",
#  'Middlesex',
#  'Ivanhoe',
#  'The Eyre Affair (Thursday Next  #1)',
#  'The Origin of Consciousness in the Breakdown of the Bicameral Mind',
#  "Hart's Hope",
#  'The Glass Castle',
#  'The Fabric of the Cosmos: Space  Time and the Texture of Reality',
#  'The Voyage of the Jerle Shannara Trilogy (Voyage of the Jerle Shannara  #1-3)',
#  'The Complete Poems',
#  "A People's History of the United States",
#  'Quicksilver (The Baroque Cycle  #1)',
#  'Casino Royale (James Bond  #1)',
#  "Jane Austen's Letters",
#  'Bleak House',
#  'The Last Unicorn',
#  'Antigone',
#  'The Bridegroom',
#  'Three Men in a Boat: To Say Nothing of the Dog',
#  'Kitchen Confidential: Adventures in the Culinary Underbelly',
#  'The Lost Painting',
#  'Ulysses',
#  'How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking',
#  "Swann's Way (Remembrance of Things Past  #1)",
#  'Brave New World',
#  'Bury the Chains',
#  'Freakonomics: A Rogue Economist Explores the Hidden Side of Everything',
#  'V for Vendetta',
#  'How to Travel with a Salmon and Other Essays',
#  'Harry Potter and the Half-Blood Prince (Harry Potter  #6)',
#  'The Hotel New Hampshire',
#  'The Art of the Personal Essay: An Anthology from the Classical Era to the Present',
#  'Lipstick Jungle',
#  'Utopia',
#  'Moll Flanders',
#  "Trickster's Choice (Daughter of the Lioness  #1)",
#  'Like Water for Chocolate',
#  'The Fellowship of the Ring (The Lord of the Rings  #1)',
#  'Jackdaws',
#  'Harry Potter and the Chamber of Secrets (Harry Potter  #2)',
#  'The Stone Raft',
#  'The Oresteia',
#  'Mystic River',
#  'The Twenty-Seventh City',
#  'The War of the Worlds',
#  'The Actor in You: Sixteen Simple Steps to Understanding the Art of Acting',
#  'Civilization and Its Discontents',
#  'Roses Are Red (Alex Cross  #6)',
#  'Anne of Avonlea',
#  'The Mating Season (Jeeves  #9)',
#  'The Other Boleyn Girl',
#  'Kafka on the Shore',
#  'Baltasar and Blimunda',
#  'Metamorphoses',
#  'The Five People You Meet in Heaven',
#  'The Secret Life of Bees',
#  'Fahrenheit 451',
#  'The Grapes of Wrath',
#  'A Random Walk Down Wall Street',
#  'The Sorrows of Young Werther',
#  'Unacknowledged Legislation: Writers in the Public Sphere',
#  'Filth',
#  'Quicksand',
#  'Daughter of Fortune',
#  'The Waste Lands (The Dark Tower  #3)',
#  'A Clockwork Orange',
#  'Night Shift',
#  'The Elements of Style',
#  'Rape: A Love Story',
#  'Shopgirl',
#  'Phaedrus',
#  'The Three Musketeers',
#  'Sodom and Gomorrah (In Search of Lost Time  #4)',
#  'Life Is a Dream',
#  'The Plot Against America',
#  'Hard Eight (Stephanie Plum  #8)',
#  'Flatland',
#  'Taxi Driver',
#  'Data Structures and Algorithms in C++',
#  'The Stephen King Collection: Stories from Night Shift',
#  'Elven Star (The Death Gate Cycle  #2)',
#  'A History of God: The 4 000-Year Quest of Judaism  Christianity  and Islam',
#  'A Painted House',
#  'Henry V',
#  'The Fountainhead',
#  'The Trial',
#  "The Color of Water: A Black Man's Tribute to His White Mother",
#  'The Art of Loving',
#  'Shadowmarch (Shadowmarch  #1)',
#  'Their Eyes Were Watching God',
#  "Aesop's Fables",
#  'The Pure in Heart (Simon Serrailler  #2)',
#  'White Fang',
#  'Introduction to Phenomenology',
#  'The Sound and the Fury',
#  'Alcoholics Anonymous',
#  "Sabbath's Theater",
#  'The Bluest Eye',
#  'The Outsiders',
#  'Madame Bovary',
#  "Bill Bryson's African Diary",
#  'The Lightning Thief (Percy Jackson and the Olympians  #1)',
#  'Ready or Not (All-American Girl  #2)',
#  'At Risk (Winston Garano  #1)',
#  'The Year of Magical Thinking',
#  'Dark Star Safari: Overland from Cairo to Cape Town',
#  'The Charterhouse of Parma',
#  'The Beach House',
#  'Gargantua and Pantagruel',
#  'The Return of the Native',
#  'The One Tree (The Second Chronicles of Thomas Covenant  #2)',
#  'A Christmas Carol',
#  'And Then There Were None',
#  '1776',
#  "In the Company of Cheerful Ladies (No. 1 Ladies' Detective Agency  #6)",
#  'Something Borrowed (Darcy & Rachel  #1)',
#  'The Changeling',
#  'The Drama of the Gifted Child: The Search for the True Self',
#  'A Streetcar Named Desire',
#  'Lincoln at Gettysburg: The Words That Remade America',
#  "The Clan of the Cave Bear (Earth's Children  #1)",
#  'I Never Promised You a Rose Garden',
#  'Narrative of the Life of Frederick Douglass: An American Slave  Written by Himself',
#  'Jazz',
#  'Anthem',
#  'The Dark Half',
#  'Beowulf',
#  'Watership Down',
#  'Naked Empire (Sword of Truth  #8)',
#  'The Adventures of Huckleberry Finn',
#  'The Talbot Odyssey',
#  'The Dark Mirror (The Bridei Chronicles  #1)',
#  'Sonnets',
#  'Call of Cthulhu: Horror Roleplaying (Call of Cthulhu RPG)',
#  'The Dharma Bums',
#  'Cover Her Face (Adam Dalgliesh #1)',
#  'A Short History of Nearly Everything',
#  'The Power of One (The Power of One  #1)',
#  'The Portrait of a Lady',
#  'The Cave',
#  'The Complete Works',
#  'Leviathan',
#  'The Merchant of Venice',
#  'Wide Sargasso Sea',
#  'The Closers (Harry Bosch  #11; Harry Bosch Universe  #14)',
#  "Gravity's Rainbow",
#  "Dead Man's Folly (Hercule Poirot  #33)",
#  'Haruki Murakami and the Music of Words',
#  "Surely You're Joking  Mr. Feynman!: Adventures of a Curious Character",
#  "I Don't Know How She Does It (Kate Reddy  #1)",
#  "The Time Traveler's Wife",
#  "Hegel's Phenomenology of Spirit",
#  'The Wonderful Story of Henry Sugar and Six More',
#  'The Other Woman',
#  'Romeo & Juliet',
#  'A Passage to India',
#  'Marvels',
#  'A Confederacy of Dunces',
#  'Boys Against Girls (Sweet Valley Twins  #17)',
#  'The Philosophy of History',
#  'Peter Pan',
#  'East of Eden',
#  'The Visitor (Jack Reacher  #4)',
#  'The House of the Spirits',
#  'Flush',
#  'The Far Pavilions',
#  'How to Stop Worrying and Start Living',
#  'Until I Find You',
#  'Dead Souls',
#  'Men Are from Mars  Women Are from Venus',
#  'Selected Writings',
#  'Hot Six (Stephanie Plum  #6)',
#  'Hunger',
#  'Sahara (Dirk Pitt  #11)',
#  'The Quiet American',
#  'The Valkyries',
#  'Dragonfly in Amber (Outlander  #2)',
#  'The Black Echo (Harry Bosch  #1; Harry Bosch Universe  #1)',
#  'The Good Earth (House of Earth  #1)',
#  'The Illustrated Man',
#  'The Alchemist',
#  'Beauty',
#  "Speaker for the Dead (Ender's Saga  #2)",
#  'Inferno',
#  'The Good Guy',
#  'Flatland: A Romance of Many Dimensions',
#  "Moonraker's Bride",
#  'Little Dorrit',
#  'The Possessed',
#  'Human Traces',
#  'The Red Tent',
#  'Wild Swans: Three Daughters of China',
#  'These Happy Golden Years (Little House  #8)',
#  'Roverandom',
#  'Flowers for Algernon',
#  'The Coming Economic Collapse: How You Can Thrive When Oil Costs $200 a Barrel',
#  'Pompeii',
#  'Metro Girl (Alex Barnaby  #1)',
#  'Trevayne',
#  'Wuthering Heights',
#  'South of the Border  West of the Sun',
#  'The Consolations of Philosophy',
#  'Excession (Culture  #5)',
#  'Everything Is Illuminated',
#  'The Wheel of Darkness (Pendergast  #8)',
#  'The Tale of Peter Rabbit',
#  'Main Street',
#  "Kurt Vonnegut's Cat's Cradle (Modern Critical Interpretations)",
#  'The Richest Man in Babylon',
#  'Candy',
#  "The Magicians' Guild (Black Magician Trilogy  #1)",
#  'The Visual Arts: A History',
#  'In Praise of Shadows',
#  'Love Smart: Find the One You Want--Fix the One You Got',
#  'Love Overboard',
#  'The Crying of Lot 49',
#  'Cold Mountain',
#  'A Secret Splendor',
#  'Fear and Loathing in Las Vegas',
#  'Far From the Madding Crowd',
#  'Timequake',
#  'The Gospel According to Jesus Christ',
#  'The Little Friend']

# %%
print(len(titles))
# Out:
# 459

# %%
karamazov_df = goodread_copy_df[(goodread_copy_df.title == 'The Brothers Karamazov')]
karamazov_df
# Out:
#                         title              author  average_rating  \
# 1286   The Brothers Karamazov  Fyodor Dostoyevsky            4.32
# 1287   The Brothers Karamazov  Fyodor Dostoyevsky            4.32
# 1288   The Brothers Karamazov  Fyodor Dostoyevsky            4.32
# 1289   The Brothers Karamazov  Fyodor Dostoyevsky            4.32
# 1290   The Brothers Karamazov  Fyodor Dostoyevsky            4.32
# 1502   The Brothers Karamazov  Fyodor Dostoyevsky            4.32
# 1843   The Brothers Karamazov  Fyodor Dostoyevsky            4.32
# 10243  The Brothers Karamazov  Fyodor Dostoyevsky            4.32
# 10345  The Brothers Karamazov  Fyodor Dostoyevsky            4.32
#
#       language_code  ratings_count  text_reviews_count publication_date  \
# 1286            eng            983                  91       1999-06-01
# 1287            eng         191531                6795       2002-06-14
# 1288            eng           1673                 184       2003-02-27
# 1289            eng            617                  80       1991-09-03
# 1290            eng           1089                 202       2004-07-25
# 1502            eng            443                  55       1992-01-16
# 1843            eng           1022                 154       1984-04-01
# 10243           eng             20                   2       2005-05-01
# 10345           eng              3                   1       2005-05-01
#
#        series
# 1286    False
# 1287    False
# 1288    False
# 1289    False
# 1290    False
# 1502    False
# 1843    False
# 10243   False
# 10345   False

# %%
print(karamazov_df['publication_date'].min())
print(karamazov_df['publication_date'].max())
print(karamazov_df['ratings_count'].sum(axis=0))
print(karamazov_df['text_reviews_count'].sum(axis=0))
# Out:
# 1984-04-01 00:00:00
# 2005-05-01 00:00:00
# 197381
# 7564

# %%
consolidated_titles = {'title': [], 'author': [], 'average_rating': [], 'language_code': [], 'series':[], 
                       'earliest_pub_date': [], 'latest_pub_date': [], 'ratings_count': [], 'text_reviews_count': []}
    
def consolidate_dupe_books(title_list, df):
    for title in title_list:
        title_df = df[(df.title == title)]
        indices_list = list(title_df.index.values)
        key_index = indices_list[0]
        consolidated_titles['title'].append(title_df['title'][key_index])
        consolidated_titles['author'].append(title_df['author'][key_index])
        consolidated_titles['average_rating'].append(title_df['average_rating'][key_index])
        consolidated_titles['language_code'].append(title_df['language_code'][key_index])
        consolidated_titles['series'].append(title_df['series'][key_index])
        consolidated_titles['earliest_pub_date'].append(title_df['publication_date'].min())
        consolidated_titles['latest_pub_date'].append(title_df['publication_date'].max())
        consolidated_titles['ratings_count'].append(title_df['ratings_count'].sum(axis=0))
        consolidated_titles['text_reviews_count'].append(title_df['text_reviews_count'].sum(axis=0))
    return consolidated_titles

# %%
consolidated_books_dict = consolidate_dupe_books(titles, goodread_copy_df)

# %%
consolidated_books_dict
# Out:
# {'title': ['The Iliad',
#   'The Brothers Karamazov',
#   'The Odyssey',
#   'Anna Karenina',
#   "Gulliver's Travels",
#   "'Salem's Lot",
#   "A Midsummer Night's Dream",
#   'The Picture of Dorian Gray',
#   'Romeo and Juliet',
#   'Sense and Sensibility',
#   'The Secret Garden',
#   'Macbeth',
#   'The Scarlet Letter',
#   'The Great Gatsby',
#   'The Histories',
#   'Collected Stories',
#   'Robinson Crusoe',
#   'Treasure Island',
#   'Frankenstein',
#   "Charlotte's Web",
#   'Don Quixote',
#   'Jane Eyre',
#   'A Tale of Two Cities',
#   'War and Peace',
#   'Much Ado about Nothing',
#   'The House of Mirth',
#   'The Shining',
#   'The Communist Manifesto',
#   'The Idiot',
#   'One Hundred Years of Solitude',
#   'Dracula',
#   'Atlas Shrugged',
#   'Paradise Lost',
#   'Eugene Onegin',
#   'The Return of the King (The Lord of the Rings  #3)',
#   'The Enemy (Jack Reacher  #8)',
#   'Pride and Prejudice',
#   'Memoirs of a Geisha',
#   'King Lear',
#   'Julius Caesar',
#   'Howards End',
#   'The Decline and Fall of the Roman Empire',
#   'Open House',
#   'Critique of Pure Reason',
#   'Emma',
#   'Twelfth Night',
#   "The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)",
#   'Crime and Punishment',
#   "Man's Search for Meaning",
#   'The Da Vinci Code (Robert Langdon  #2)',
#   'Billy Budd  Sailor',
#   'Lolita',
#   'The Woman in White',
#   'Great Expectations',
#   'Selected Poems',
#   'The Complete Stories',
#   'The Invisible Man',
#   'Hamlet',
#   'Sula',
#   'Little Women',
#   'Mansfield Park',
#   'Tripwire (Jack Reacher  #3)',
#   'The Aeneid',
#   'The Known World',
#   'Les Misérables',
#   'White Teeth',
#   'The Complete Plays',
#   'The Lord of the Rings (The Lord of the Rings  #1-3)',
#   'Love',
#   'Othello',
#   'Far from the Madding Crowd',
#   'Starship Troopers',
#   'Angels & Demons (Robert Langdon  #1)',
#   "Alice's Adventures in Wonderland",
#   'John Adams',
#   'The Lovely Bones',
#   'The Call of the Wild',
#   'The Count of Monte Cristo',
#   'Moby Dick',
#   'Last Man Standing',
#   'The Complete Novels',
#   'Heart of Darkness',
#   'The Canterbury Tales',
#   'The Moonstone',
#   'Lysistrata',
#   'As You Like It',
#   'The Last Kingdom (The Saxon Stories  #1)',
#   'The Art of War',
#   'Selected Stories',
#   'Kim',
#   'Vanity Fair',
#   'The Epic of Gilgamesh',
#   'The Long Goodbye (Philip Marlowe  #6)',
#   'The Time Machine',
#   'The Poisonwood Bible',
#   'The Metamorphosis and Other Stories',
#   'A Portrait of the Artist as a Young Man',
#   'The Silmarillion',
#   'Blink: The Power of Thinking Without Thinking',
#   'The Divine Comedy',
#   'Magician: Apprentice (The Riftwar Saga  #1)',
#   'Dubliners',
#   'James and the Giant Peach',
#   'To Kill a Mockingbird',
#   'The Hound of the Baskervilles',
#   'Cyrano de Bergerac',
#   'Nicomachean Ethics',
#   'The Eternity Code (Artemis Fowl  #3)',
#   'The Mill on the Floss',
#   'On the Road',
#   'Cry  the Beloved Country',
#   'The Birth of Tragedy',
#   'The Sea',
#   'Lord of the Flies',
#   'Act of Treason (Mitch Rapp  #9)',
#   'The Subtle Knife (His Dark Materials  #2)',
#   'A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#   'Siddhartha',
#   'Persuasion',
#   "The Handmaid's Tale",
#   'Matilda',
#   'Oliver Twist',
#   'In Cold Blood',
#   'Moby-Dick',
#   'Never Let Me Go',
#   'The Curious Incident of the Dog in the Night-Time',
#   'Deception Point',
#   'Adventures of Huckleberry Finn',
#   'Haunted',
#   'The Origin of Species',
#   'King Richard II',
#   'The Book of Five Rings',
#   'A Little Princess',
#   'Doctor Faustus',
#   'The Metamorphosis',
#   "A Room of One's Own",
#   'The Silver Pigs (Marcus Didius Falco  #1)',
#   'Light in August',
#   'English Passengers',
#   'Democracy in America',
#   'Five Quarters of the Orange',
#   'The Echo Maker',
#   'Echo Park (Harry Bosch  #12; Harry Bosch Universe  #16)',
#   "Midnight's Children",
#   'Before Night Falls',
#   'Bargaining for Advantage: Negotiation Strategies for Reasonable People',
#   'Conversations with Bernard Malamud (Literary Conversations)',
#   "The Prime of Miss Jean Brodie / The Girls of Slender Means / The Driver's Seat / The Only Problem",
#   'Beloved',
#   "Girls' Night In",
#   'Five Patients',
#   'Mere Christianity',
#   'To the Lighthouse',
#   "My Sister's Keeper",
#   'The Damned (Vampire Huntress  #6)',
#   'The Locked Room (The New York Trilogy  #3)',
#   'The Illustrated A Brief History of Time',
#   'The Da Vinci Code',
#   'Casino Royale',
#   'The Short Stories',
#   'Them: Adventures with Extremists',
#   'The Republic',
#   'Nineteen Eighty-Four',
#   'Black Beauty',
#   'The Poet (Jack McEvoy  #1; Harry Bosch Universe  #5)',
#   'Philosophical Investigations',
#   'Love in the Time of Cholera',
#   'Danny the Champion of the World',
#   'Are We There Yet?',
#   'Monkey Business',
#   'How to Win Friends and Influence People',
#   "A Hard Day's Write: The Stories Behind Every Beatles Song",
#   'Rob Roy',
#   'Candide: or  Optimism',
#   'Sputnik Sweetheart',
#   'Swan Song',
#   'The Heart Is a Lonely Hunter',
#   'Slow Learner: Early Stories',
#   'Tara Road',
#   'Blackberry Wine',
#   'Fierce Invalids Home from Hot Climates',
#   'The Journals of Sylvia Plath',
#   'Foxmask (Saga of the Light Isles  #2)',
#   'The Best American Mystery Stories 2004',
#   'The Guardian',
#   'Around the World in Eighty Days',
#   'The Hunchback of Notre-Dame',
#   'Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)',
#   'Americana',
#   'Dry',
#   'Different Seasons',
#   'The Sea of Monsters (Percy Jackson and the Olympians  #2)',
#   'Blind Willow  Sleeping Woman',
#   'Tehanu (Earthsea Cycle  #4)',
#   'Pygmalion',
#   'The Autograph Man',
#   'Republic',
#   'Song of Solomon',
#   'The Castle of Otranto',
#   'Choke',
#   "The Botany of Desire: A Plant's-Eye View of the World",
#   'Icebound',
#   'An Instance of the Fingerpost',
#   "The Dirt: Confessions of the World's Most Notorious Rock Band",
#   'The Tale of Genji',
#   'While I Was Gone',
#   'Mysteries',
#   'The Gunslinger',
#   'Nimitz Class (Admiral Arnold Morgan  #1)',
#   'Trace (Kay Scarpetta  #13)',
#   'Babyville',
#   'Heat',
#   "Alice's Adventures in Wonderland & Through the Looking-Glass",
#   'White Oleander',
#   'The Second Sex',
#   'Message in a Bottle',
#   'The Adventures of Tom Sawyer (Adventures of Tom and Huck  #1)',
#   'Identity',
#   'The Major Works',
#   'Middlemarch',
#   'The Sun Also Rises',
#   'Murder on the Orient Express (Hercule Poirot  #10)',
#   'The Pact',
#   'To Sail Beyond the Sunset',
#   'Murder at the Vicarage (Miss Marple  #1)',
#   'The Damnation Game',
#   'In the Shadow of Young Girls in Flower (In Search of Lost Time  #2)',
#   'The Presocratic Philosophers',
#   'A Farewell to Arms',
#   'Phantoms',
#   'Bookends',
#   'Basket Case',
#   'The Stranger',
#   'Marie Antoinette: The Journey',
#   'The 9/11 Commission Report: Final Report of the National Commission on Terrorist Attacks Upon the United States',
#   'Faust  Part Two',
#   "The Bonesetter's Daughter",
#   'Middlesex',
#   'Ivanhoe',
#   'The Eyre Affair (Thursday Next  #1)',
#   'The Origin of Consciousness in the Breakdown of the Bicameral Mind',
#   "Hart's Hope",
#   'The Glass Castle',
#   'The Fabric of the Cosmos: Space  Time and the Texture of Reality',
#   'The Voyage of the Jerle Shannara Trilogy (Voyage of the Jerle Shannara  #1-3)',
#   'The Complete Poems',
#   "A People's History of the United States",
#   'Quicksilver (The Baroque Cycle  #1)',
#   'Casino Royale (James Bond  #1)',
#   "Jane Austen's Letters",
#   'Bleak House',
#   'The Last Unicorn',
#   'Antigone',
#   'The Bridegroom',
#   'Three Men in a Boat: To Say Nothing of the Dog',
#   'Kitchen Confidential: Adventures in the Culinary Underbelly',
#   'The Lost Painting',
#   'Ulysses',
#   'How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking',
#   "Swann's Way (Remembrance of Things Past  #1)",
#   'Brave New World',
#   'Bury the Chains',
#   'Freakonomics: A Rogue Economist Explores the Hidden Side of Everything',
#   'V for Vendetta',
#   'How to Travel with a Salmon and Other Essays',
#   'Harry Potter and the Half-Blood Prince (Harry Potter  #6)',
#   'The Hotel New Hampshire',
#   'The Art of the Personal Essay: An Anthology from the Classical Era to the Present',
#   'Lipstick Jungle',
#   'Utopia',
#   'Moll Flanders',
#   "Trickster's Choice (Daughter of the Lioness  #1)",
#   'Like Water for Chocolate',
#   'The Fellowship of the Ring (The Lord of the Rings  #1)',
#   'Jackdaws',
#   'Harry Potter and the Chamber of Secrets (Harry Potter  #2)',
#   'The Stone Raft',
#   'The Oresteia',
#   'Mystic River',
#   'The Twenty-Seventh City',
#   'The War of the Worlds',
#   'The Actor in You: Sixteen Simple Steps to Understanding the Art of Acting',
#   'Civilization and Its Discontents',
#   'Roses Are Red (Alex Cross  #6)',
#   'Anne of Avonlea',
#   'The Mating Season (Jeeves  #9)',
#   'The Other Boleyn Girl',
#   'Kafka on the Shore',
#   'Baltasar and Blimunda',
#   'Metamorphoses',
#   'The Five People You Meet in Heaven',
#   'The Secret Life of Bees',
#   'Fahrenheit 451',
#   'The Grapes of Wrath',
#   'A Random Walk Down Wall Street',
#   'The Sorrows of Young Werther',
#   'Unacknowledged Legislation: Writers in the Public Sphere',
#   'Filth',
#   'Quicksand',
#   'Daughter of Fortune',
#   'The Waste Lands (The Dark Tower  #3)',
#   'A Clockwork Orange',
#   'Night Shift',
#   'The Elements of Style',
#   'Rape: A Love Story',
#   'Shopgirl',
#   'Phaedrus',
#   'The Three Musketeers',
#   'Sodom and Gomorrah (In Search of Lost Time  #4)',
#   'Life Is a Dream',
#   'The Plot Against America',
#   'Hard Eight (Stephanie Plum  #8)',
#   'Flatland',
#   'Taxi Driver',
#   'Data Structures and Algorithms in C++',
#   'The Stephen King Collection: Stories from Night Shift',
#   'Elven Star (The Death Gate Cycle  #2)',
#   'A History of God: The 4 000-Year Quest of Judaism  Christianity  and Islam',
#   'A Painted House',
#   'Henry V',
#   'The Fountainhead',
#   'The Trial',
#   "The Color of Water: A Black Man's Tribute to His White Mother",
#   'The Art of Loving',
#   'Shadowmarch (Shadowmarch  #1)',
#   'Their Eyes Were Watching God',
#   "Aesop's Fables",
#   'The Pure in Heart (Simon Serrailler  #2)',
#   'White Fang',
#   'Introduction to Phenomenology',
#   'The Sound and the Fury',
#   'Alcoholics Anonymous',
#   "Sabbath's Theater",
#   'The Bluest Eye',
#   'The Outsiders',
#   'Madame Bovary',
#   "Bill Bryson's African Diary",
#   'The Lightning Thief (Percy Jackson and the Olympians  #1)',
#   'Ready or Not (All-American Girl  #2)',
#   'At Risk (Winston Garano  #1)',
#   'The Year of Magical Thinking',
#   'Dark Star Safari: Overland from Cairo to Cape Town',
#   'The Charterhouse of Parma',
#   'The Beach House',
#   'Gargantua and Pantagruel',
#   'The Return of the Native',
#   'The One Tree (The Second Chronicles of Thomas Covenant  #2)',
#   'A Christmas Carol',
#   'And Then There Were None',
#   '1776',
#   "In the Company of Cheerful Ladies (No. 1 Ladies' Detective Agency  #6)",
#   'Something Borrowed (Darcy & Rachel  #1)',
#   'The Changeling',
#   'The Drama of the Gifted Child: The Search for the True Self',
#   'A Streetcar Named Desire',
#   'Lincoln at Gettysburg: The Words That Remade America',
#   "The Clan of the Cave Bear (Earth's Children  #1)",
#   'I Never Promised You a Rose Garden',
#   'Narrative of the Life of Frederick Douglass: An American Slave  Written by Himself',
#   'Jazz',
#   'Anthem',
#   'The Dark Half',
#   'Beowulf',
#   'Watership Down',
#   'Naked Empire (Sword of Truth  #8)',
#   'The Adventures of Huckleberry Finn',
#   'The Talbot Odyssey',
#   'The Dark Mirror (The Bridei Chronicles  #1)',
#   'Sonnets',
#   'Call of Cthulhu: Horror Roleplaying (Call of Cthulhu RPG)',
#   'The Dharma Bums',
#   'Cover Her Face (Adam Dalgliesh #1)',
#   'A Short History of Nearly Everything',
#   'The Power of One (The Power of One  #1)',
#   'The Portrait of a Lady',
#   'The Cave',
#   'The Complete Works',
#   'Leviathan',
#   'The Merchant of Venice',
#   'Wide Sargasso Sea',
#   'The Closers (Harry Bosch  #11; Harry Bosch Universe  #14)',
#   "Gravity's Rainbow",
#   "Dead Man's Folly (Hercule Poirot  #33)",
#   'Haruki Murakami and the Music of Words',
#   "Surely You're Joking  Mr. Feynman!: Adventures of a Curious Character",
#   "I Don't Know How She Does It (Kate Reddy  #1)",
#   "The Time Traveler's Wife",
#   "Hegel's Phenomenology of Spirit",
#   'The Wonderful Story of Henry Sugar and Six More',
#   'The Other Woman',
#   'Romeo & Juliet',
#   'A Passage to India',
#   'Marvels',
#   'A Confederacy of Dunces',
#   'Boys Against Girls (Sweet Valley Twins  #17)',
#   'The Philosophy of History',
#   'Peter Pan',
#   'East of Eden',
#   'The Visitor (Jack Reacher  #4)',
#   'The House of the Spirits',
#   'Flush',
#   'The Far Pavilions',
#   'How to Stop Worrying and Start Living',
#   'Until I Find You',
#   'Dead Souls',
#   'Men Are from Mars  Women Are from Venus',
#   'Selected Writings',
#   'Hot Six (Stephanie Plum  #6)',
#   'Hunger',
#   'Sahara (Dirk Pitt  #11)',
#   'The Quiet American',
#   'The Valkyries',
#   'Dragonfly in Amber (Outlander  #2)',
#   'The Black Echo (Harry Bosch  #1; Harry Bosch Universe  #1)',
#   'The Good Earth (House of Earth  #1)',
#   'The Illustrated Man',
#   'The Alchemist',
#   'Beauty',
#   "Speaker for the Dead (Ender's Saga  #2)",
#   'Inferno',
#   'The Good Guy',
#   'Flatland: A Romance of Many Dimensions',
#   "Moonraker's Bride",
#   'Little Dorrit',
#   'The Possessed',
#   'Human Traces',
#   'The Red Tent',
#   'Wild Swans: Three Daughters of China',
#   'These Happy Golden Years (Little House  #8)',
#   'Roverandom',
#   'Flowers for Algernon',
#   'The Coming Economic Collapse: How You Can Thrive When Oil Costs $200 a Barrel',
#   'Pompeii',
#   'Metro Girl (Alex Barnaby  #1)',
#   'Trevayne',
#   'Wuthering Heights',
#   'South of the Border  West of the Sun',
#   'The Consolations of Philosophy',
#   'Excession (Culture  #5)',
#   'Everything Is Illuminated',
#   'The Wheel of Darkness (Pendergast  #8)',
#   'The Tale of Peter Rabbit',
#   'Main Street',
#   "Kurt Vonnegut's Cat's Cradle (Modern Critical Interpretations)",
#   'The Richest Man in Babylon',
#   'Candy',
#   "The Magicians' Guild (Black Magician Trilogy  #1)",
#   'The Visual Arts: A History',
#   'In Praise of Shadows',
#   'Love Smart: Find the One You Want--Fix the One You Got',
#   'Love Overboard',
#   'The Crying of Lot 49',
#   'Cold Mountain',
#   'A Secret Splendor',
#   'Fear and Loathing in Las Vegas',
#   'Far From the Madding Crowd',
#   'Timequake',
#   'The Gospel According to Jesus Christ',
#   'The Little Friend'],
#  'author': ['Homer',
#   'Fyodor Dostoyevsky',
#   'Homer',
#   'Leo Tolstoy',
#   'Jonathan Swift',
#   'Stephen King',
#   'William Shakespeare',
#   'Oscar Wilde',
#   'William Shakespeare',
#   'Jane Austen',
#   'Frances Hodgson Burnett',
#   'William Shakespeare',
#   'Nathaniel Hawthorne',
#   'Kathleen Parkinson',
#   'Herodotus',
#   'Gabriel García Márquez',
#   'Daniel Defoe',
#   'Robert Louis Stevenson',
#   'Mary Wollstonecraft Shelley',
#   'E.B. White',
#   'Miguel de Cervantes Saavedra',
#   'Charlotte Brontë',
#   'Charles Dickens',
#   'Leo Tolstoy',
#   'William Shakespeare',
#   'Edith Wharton',
#   'Stephen King',
#   'Karl Marx',
#   'Fyodor Dostoyevsky',
#   'Gabriel García Márquez',
#   'Bram Stoker',
#   'Ayn Rand',
#   'John Milton',
#   'Alexander Pushkin',
#   'J.R.R. Tolkien',
#   'Lee Child',
#   'Jane Austen',
#   'Arthur Golden',
#   'William Shakespeare',
#   'William Shakespeare',
#   'E.M. Forster',
#   'Edward Gibbon',
#   'Elizabeth Berg',
#   'Immanuel Kant',
#   'Jane Austen',
#   'William Shakespeare',
#   'Douglas Adams',
#   'Fyodor Dostoyevsky',
#   'Viktor E. Frankl',
#   'Dan Brown',
#   'Herman Melville',
#   'Vladimir Nabokov',
#   'Wilkie Collins',
#   'Charles Dickens',
#   'Octavio Paz',
#   'Bernard Malamud',
#   'H.G. Wells',
#   'William Shakespeare',
#   'Toni Morrison',
#   'Louisa May Alcott',
#   'Jane Austen',
#   'Lee Child',
#   'Virgil',
#   'Edward P. Jones',
#   'Victor Hugo',
#   'Zadie Smith',
#   'Sophocles',
#   'J.R.R. Tolkien',
#   'Pablo Neruda',
#   'William Shakespeare',
#   'Thomas Hardy',
#   'Robert A. Heinlein',
#   'Dan Brown',
#   'Lewis Carroll',
#   'David McCullough',
#   'Alice Sebold',
#   'Jack London',
#   'Alexandre Dumas',
#   'Herman Melville',
#   'David Baldacci',
#   'Jane Austen',
#   'Joseph Conrad',
#   'Geoffrey Chaucer',
#   'Wilkie Collins',
#   'Aristophanes',
#   'William Shakespeare',
#   'Bernard Cornwell',
#   'Mao Zedong',
#   'H.G. Wells',
#   'Rudyard Kipling',
#   'William Makepeace Thackeray',
#   'Anonymous',
#   'Raymond Chandler',
#   'H.G. Wells',
#   'Barbara Kingsolver',
#   'Franz Kafka',
#   'James Joyce',
#   'J.R.R. Tolkien',
#   'Malcolm Gladwell',
#   'Dante Alighieri',
#   'Raymond E. Feist',
#   'James Joyce',
#   'Roald Dahl',
#   'Harper Lee',
#   'Arthur Conan Doyle',
#   'Edmond Rostand',
#   'Aristotle',
#   'Eoin Colfer',
#   'George Eliot',
#   'Jack Kerouac',
#   'Alan Paton',
#   'Friedrich Nietzsche',
#   'John Banville',
#   'William Golding',
#   'Vince Flynn',
#   'Philip Pullman',
#   'Bill Bryson',
#   'Hermann Hesse',
#   'Jane Austen',
#   'Margaret Atwood',
#   'Roald Dahl',
#   'Charles Dickens',
#   'Truman Capote',
#   'Jan Needle',
#   'Kazuo Ishiguro',
#   'Mark Haddon',
#   'Dan Brown',
#   'Mark Twain',
#   'Chuck Palahniuk',
#   'Charles Darwin',
#   'William Shakespeare',
#   'Miyamoto Musashi',
#   'Frances Hodgson Burnett',
#   'Thomas Mann',
#   'Peter Kuper',
#   'Virginia Woolf',
#   'Lindsey Davis',
#   'William Faulkner',
#   'Matthew Kneale',
#   'Alexis de Tocqueville',
#   'Joanne Harris',
#   'Richard Powers',
#   'Michael Connelly',
#   'Salman Rushdie',
#   'Reinaldo Arenas',
#   'G. Richard Shell',
#   'Lawrence M. Lasher',
#   'Muriel Spark',
#   'Toni Morrison',
#   'Lauren Henderson',
#   'Michael Crichton',
#   'C.S. Lewis',
#   'Virginia Woolf',
#   'Mavis Applewater',
#   'L.A. Banks',
#   'Paul Auster',
#   'Stephen Hawking',
#   'Dan Brown',
#   'Ian Fleming',
#   'Ernest Hemingway',
#   'Jon Ronson',
#   'Plato',
#   'George Orwell',
#   'Anna Sewell',
#   'Michael Connelly',
#   'Ludwig Wittgenstein',
#   'Gabriel García Márquez',
#   'Roald Dahl',
#   'David Levithan',
#   'Sarah Mlynowski',
#   'Dale Carnegie',
#   'Steve Turner',
#   'Walter Scott',
#   'Voltaire',
#   'Haruki Murakami',
#   'Robert R. McCammon',
#   'Carson McCullers',
#   'Thomas Pynchon',
#   'Maeve Binchy',
#   'Joanne Harris',
#   'Tom Robbins',
#   'Sylvia Plath',
#   'Juliet Marillier',
#   'Nelson DeMille',
#   'Jane Hamilton',
#   'Jules Verne',
#   'Victor Hugo',
#   'J.K. Rowling',
#   'Don DeLillo',
#   'Augusten Burroughs',
#   'Stephen King',
#   'Rick Riordan',
#   'Haruki Murakami',
#   'Ursula K. Le Guin',
#   'George Bernard Shaw',
#   'Zadie Smith',
#   'Plato',
#   'Toni Morrison',
#   'Horace Walpole',
#   'Stuart Woods',
#   'Michael Pollan',
#   'David Axton',
#   'Iain Pears',
#   'Neil Strauss',
#   'Murasaki Shikibu',
#   'Sue Miller',
#   'Knut Hamsun',
#   'Stephen King',
#   'Patrick Robinson',
#   'Patricia Cornwell',
#   'Jane Green',
#   'William Goldman',
#   'Lewis Carroll',
#   'Janet Fitch',
#   'Simone de Beauvoir',
#   'Nicholas Sparks',
#   'Mark Twain',
#   'Milan Kundera',
#   'John Milton',
#   'George Eliot',
#   'Ernest Hemingway',
#   'Agatha Christie',
#   'Jodi Picoult',
#   'Robert A. Heinlein',
#   'Agatha Christie',
#   'Clive Barker',
#   'Marcel Proust',
#   'Geoffrey S. Kirk',
#   'Ernest Hemingway',
#   'Rosalind M. Greenberg',
#   'Jane Green',
#   'Carl Hiaasen',
#   'Caroline B. Cooney',
#   'Antonia Fraser',
#   'National Commission on Terrorist Attacks Upon The United States',
#   'Johann Wolfgang von Goethe',
#   'Amy Tan',
#   'Jeffrey Eugenides',
#   'Walter Scott',
#   'Jasper Fforde',
#   'Julian Jaynes',
#   'Orson Scott Card',
#   'Jeannette Walls',
#   'Brian Greene',
#   'Terry Brooks',
#   'William Blake',
#   'Howard Zinn',
#   'Neal Stephenson',
#   'Ian Fleming',
#   'Jane Austen',
#   'Charles Dickens',
#   'Peter S. Beagle',
#   'Sophocles',
#   'Ha Jin',
#   'Jerome K. Jerome',
#   'Anthony Bourdain',
#   'Jonathan Harr',
#   'James Joyce',
#   'Nigella Lawson',
#   'Marcel Proust',
#   'Aldous Huxley',
#   'Adam Hochschild',
#   'Steven D. Levitt',
#   'Alan Moore',
#   'Umberto Eco',
#   'J.K. Rowling',
#   'John Irving',
#   'Phillip Lopate',
#   'Candace Bushnell',
#   'Thomas More',
#   'Daniel Defoe',
#   'Tamora Pierce',
#   'Laura Esquivel',
#   'J.R.R. Tolkien',
#   'Ken Follett',
#   'J.K. Rowling',
#   'José Saramago',
#   'Aeschylus',
#   'Dennis Lehane',
#   'Jonathan Franzen',
#   'H.G. Wells',
#   'Robert Benedetti',
#   'Sigmund Freud',
#   'James Patterson',
#   'L.M. Montgomery',
#   'P.G. Wodehouse',
#   'Philippa Gregory',
#   'Haruki Murakami',
#   'José Saramago',
#   'Ovid',
#   'Mitch Albom',
#   'Sue Monk Kidd',
#   'Ray Bradbury',
#   'John Steinbeck',
#   'Burton G. Malkiel',
#   'Johann Wolfgang von Goethe',
#   'Christopher Hitchens',
#   'Irvine Welsh',
#   'Nella Larsen',
#   'Isabel Allende',
#   'Stephen King',
#   'Anthony Burgess',
#   'Stephen King',
#   'William Strunk Jr.',
#   'Joyce Carol Oates',
#   'Steve Martin',
#   'Plato',
#   'Alexandre Dumas',
#   'Marcel Proust',
#   'Pedro Calderón de la Barca',
#   'Philip Roth',
#   'Janet Evanovich',
#   'Edwin A. Abbott',
#   'Amy Taubin',
#   'Adam Drozdek',
#   'Stephen King',
#   'Margaret Weis',
#   'Karen Armstrong',
#   'John Grisham',
#   'William Shakespeare',
#   'Ayn Rand',
#   'Franz Kafka',
#   'James   McBride',
#   'Erich Fromm',
#   'Tad Williams',
#   'Zora Neale Hurston',
#   'Aesop',
#   'Susan Hill',
#   'Jack London',
#   'Dermot Moran',
#   'William Faulkner',
#   'Alcoholics Anonymous',
#   'Philip Roth',
#   'Toni Morrison',
#   'S.E. Hinton',
#   'Gustave Flaubert',
#   'Bill Bryson',
#   'Rick Riordan',
#   'Meg Cabot',
#   'Patricia Cornwell',
#   'Joan Didion',
#   'Paul Theroux',
#   'Stendhal',
#   'James Patterson',
#   'François Rabelais',
#   'Thomas Hardy',
#   'Stephen R. Donaldson',
#   'Charles Dickens',
#   'Agatha Christie',
#   'David McCullough',
#   'Alexander McCall Smith',
#   'Emily Giffin',
#   'Zilpha Keatley Snyder',
#   'Alice   Miller',
#   'Tennessee Williams',
#   'Garry Wills',
#   'Jean M. Auel',
#   'Hannah  Green',
#   'Frederick Douglass',
#   'Toni Morrison',
#   'Ayn Rand',
#   'Stephen King',
#   'Unknown',
#   'Richard  Adams',
#   'Terry Goodkind',
#   'Mark Twain',
#   'Nelson DeMille',
#   'Juliet Marillier',
#   'William Shakespeare',
#   'Sandy Petersen',
#   'Jack Kerouac',
#   'P.D. James',
#   'Bill Bryson',
#   'Bryce Courtenay',
#   'Henry James',
#   'José Saramago',
#   'William Shakespeare',
#   'Paul Auster',
#   'William Shakespeare',
#   'Jean Rhys',
#   'Michael Connelly',
#   'Thomas Pynchon',
#   'Agatha Christie',
#   'Jay Rubin',
#   'Richard P. Feynman',
#   'Allison Pearson',
#   'Audrey Niffenegger',
#   'Georg Wilhelm Friedrich Hegel',
#   'Roald Dahl',
#   'Jane Green',
#   'William Shakespeare',
#   'E.M. Forster',
#   'Kurt Busiek',
#   'John Kennedy Toole',
#   'Francine Pascal',
#   'Georg Wilhelm Friedrich Hegel',
#   'J.M. Barrie',
#   'John Steinbeck',
#   'Lee Child',
#   'Isabel Allende',
#   'Carl Hiaasen',
#   'M.M. Kaye',
#   'Dale Carnegie',
#   'John Irving',
#   'Nikolai Gogol',
#   'John Gray',
#   'Thomas Aquinas',
#   'Janet Evanovich',
#   'Lan Samantha Chang',
#   'Clive Cussler',
#   'Graham Greene',
#   'Paulo Coelho',
#   'Diana Gabaldon',
#   'Michael Connelly',
#   'Pearl S. Buck',
#   'Ray Bradbury',
#   'Paulo Coelho',
#   'Robin McKinley',
#   'Orson Scott Card',
#   'Dante Alighieri',
#   'Dean Koontz',
#   'Edwin A. Abbott',
#   'Madeleine Brent',
#   'Charles Dickens',
#   'Fyodor Dostoyevsky',
#   'Sebastian Faulks',
#   'Anita Diamant',
#   'Jung Chang',
#   'Laura Ingalls Wilder',
#   'J.R.R. Tolkien',
#   'Daniel Keyes',
#   'Stephen Leeb',
#   'Robert   Harris',
#   'Janet Evanovich',
#   'Robert Ludlum',
#   'Emily Brontë',
#   'Haruki Murakami',
#   'Alain de Botton',
#   'Iain M. Banks',
#   'Jonathan Safran Foer',
#   'Douglas Preston',
#   'Beatrix Potter',
#   'Sinclair Lewis',
#   'Harold Bloom',
#   'George S. Clason',
#   'Luke Davies',
#   'Trudi Canavan',
#   'Hugh Honour',
#   "Jun'ichirō Tanizaki",
#   'Phillip C. McGraw',
#   'Janet Evanovich',
#   'Thomas Pynchon',
#   'Charles Frazier',
#   'Erin St. Claire',
#   'Hunter S. Thompson',
#   'Thomas Hardy',
#   'Kurt Vonnegut Jr.',
#   'José Saramago',
#   'Donna Tartt'],
#  'average_rating': [3.86,
#   4.32,
#   3.76,
#   4.05,
#   3.57,
#   4.25,
#   3.94,
#   4.08,
#   3.74,
#   4.07,
#   4.13,
#   3.9,
#   3.4,
#   3.88,
#   3.99,
#   4.19,
#   3.67,
#   3.83,
#   3.79,
#   4.17,
#   3.87,
#   4.12,
#   3.84,
#   4.11,
#   4.07,
#   3.95,
#   4.22,
#   3.55,
#   4.18,
#   4.07,
#   3.99,
#   3.69,
#   3.82,
#   4.09,
#   4.53,
#   4.16,
#   4.26,
#   4.11,
#   3.91,
#   3.68,
#   3.96,
#   3.98,
#   3.7,
#   3.94,
#   4.0,
#   3.98,
#   4.22,
#   4.21,
#   4.36,
#   3.84,
#   3.12,
#   3.89,
#   4.0,
#   3.77,
#   4.21,
#   4.22,
#   3.64,
#   4.02,
#   3.93,
#   4.07,
#   3.86,
#   4.09,
#   3.84,
#   3.83,
#   4.17,
#   3.77,
#   4.27,
#   4.5,
#   4.46,
#   3.89,
#   3.94,
#   4.01,
#   3.89,
#   4.02,
#   4.06,
#   3.81,
#   3.86,
#   4.25,
#   3.5,
#   4.04,
#   4.55,
#   3.42,
#   3.49,
#   3.91,
#   3.85,
#   3.83,
#   4.25,
#   4.2,
#   3.93,
#   3.72,
#   3.79,
#   3.68,
#   4.22,
#   3.89,
#   4.06,
#   4.03,
#   3.61,
#   3.92,
#   3.93,
#   4.07,
#   4.17,
#   3.85,
#   4.01,
#   4.27,
#   4.11,
#   4.06,
#   3.94,
#   4.04,
#   3.79,
#   3.63,
#   3.9,
#   3.98,
#   3.51,
#   3.68,
#   4.29,
#   4.13,
#   4.06,
#   4.02,
#   4.14,
#   4.11,
#   4.31,
#   3.86,
#   4.07,
#   3.71,
#   3.82,
#   3.88,
#   3.71,
#   3.82,
#   3.59,
#   3.98,
#   3.77,
#   4.07,
#   4.2,
#   4.08,
#   3.79,
#   4.14,
#   3.94,
#   3.94,
#   4.06,
#   4.02,
#   3.85,
#   3.38,
#   4.12,
#   3.98,
#   4.17,
#   3.95,
#   4.0,
#   3.79,
#   3.83,
#   3.63,
#   3.48,
#   4.32,
#   3.78,
#   3.86,
#   4.28,
#   3.89,
#   4.17,
#   3.84,
#   3.73,
#   4.26,
#   3.95,
#   3.94,
#   4.18,
#   3.96,
#   4.2,
#   4.23,
#   3.91,
#   4.09,
#   3.49,
#   3.67,
#   4.19,
#   4.18,
#   3.7,
#   3.77,
#   3.83,
#   4.28,
#   3.98,
#   3.5,
#   3.9,
#   3.8,
#   4.03,
#   4.17,
#   4.1,
#   3.55,
#   3.72,
#   3.93,
#   4.0,
#   4.56,
#   3.43,
#   4.03,
#   4.35,
#   4.24,
#   3.84,
#   3.94,
#   3.9,
#   3.16,
#   3.94,
#   4.06,
#   3.18,
#   3.84,
#   4.06,
#   3.76,
#   3.94,
#   4.16,
#   3.72,
#   3.69,
#   4.09,
#   3.96,
#   3.92,
#   3.78,
#   3.62,
#   3.37,
#   4.07,
#   3.96,
#   4.12,
#   3.96,
#   3.91,
#   3.68,
#   4.24,
#   3.96,
#   3.82,
#   4.17,
#   4.01,
#   3.87,
#   4.05,
#   3.82,
#   4.4,
#   4.25,
#   3.8,
#   3.38,
#   3.72,
#   3.82,
#   3.53,
#   3.93,
#   3.6,
#   3.73,
#   3.99,
#   4.0,
#   3.75,
#   3.91,
#   4.25,
#   3.47,
#   4.27,
#   4.11,
#   4.27,
#   4.24,
#   4.08,
#   3.93,
#   3.73,
#   4.16,
#   4.01,
#   4.17,
#   3.64,
#   3.77,
#   3.89,
#   4.07,
#   3.74,
#   3.73,
#   3.97,
#   4.14,
#   3.99,
#   4.28,
#   3.97,
#   4.25,
#   3.85,
#   4.57,
#   3.9,
#   4.19,
#   3.41,
#   3.53,
#   3.52,
#   4.27,
#   3.95,
#   4.36,
#   3.97,
#   4.42,
#   3.8,
#   4.02,
#   4.18,
#   3.12,
#   3.82,
#   3.65,
#   3.78,
#   4.04,
#   4.23,
#   4.26,
#   4.06,
#   4.14,
#   3.92,
#   4.05,
#   3.93,
#   4.05,
#   3.99,
#   3.96,
#   4.1,
#   3.67,
#   4.01,
#   3.73,
#   3.68,
#   3.91,
#   4.24,
#   3.99,
#   4.0,
#   4.19,
#   3.57,
#   3.43,
#   3.92,
#   4.07,
#   4.35,
#   3.98,
#   3.77,
#   4.17,
#   3.82,
#   3.93,
#   3.8,
#   4.0,
#   3.99,
#   3.87,
#   3.7,
#   3.88,
#   3.87,
#   3.98,
#   4.09,
#   4.04,
#   3.73,
#   3.91,
#   4.05,
#   3.92,
#   3.98,
#   4.18,
#   3.86,
#   4.45,
#   3.85,
#   4.03,
#   4.09,
#   3.67,
#   3.44,
#   4.25,
#   3.4,
#   3.41,
#   3.89,
#   3.96,
#   3.82,
#   3.84,
#   3.71,
#   3.86,
#   3.98,
#   4.05,
#   4.26,
#   4.07,
#   4.08,
#   3.85,
#   4.17,
#   4.09,
#   3.98,
#   4.14,
#   4.05,
#   3.87,
#   4.02,
#   3.81,
#   3.63,
#   3.77,
#   3.44,
#   4.06,
#   3.81,
#   3.82,
#   3.85,
#   3.97,
#   4.25,
#   4.45,
#   3.92,
#   3.93,
#   4.21,
#   4.35,
#   3.78,
#   3.84,
#   4.5,
#   3.96,
#   3.8,
#   3.58,
#   4.13,
#   4.01,
#   3.79,
#   3.83,
#   4.28,
#   3.33,
#   3.97,
#   3.93,
#   4.14,
#   3.7,
#   3.74,
#   3.68,
#   4.22,
#   3.89,
#   3.47,
#   3.82,
#   4.08,
#   4.37,
#   4.09,
#   4.23,
#   3.88,
#   4.21,
#   4.12,
#   3.63,
#   3.99,
#   3.55,
#   3.91,
#   4.19,
#   3.92,
#   3.96,
#   3.97,
#   3.31,
#   4.32,
#   4.1,
#   3.98,
#   4.14,
#   3.86,
#   4.05,
#   4.07,
#   4.0,
#   3.82,
#   3.82,
#   4.31,
#   3.99,
#   4.27,
#   3.63,
#   4.17,
#   4.26,
#   4.19,
#   3.87,
#   4.12,
#   3.4,
#   3.82,
#   3.62,
#   3.62,
#   3.85,
#   3.87,
#   4.01,
#   4.21,
#   3.9,
#   3.93,
#   4.18,
#   3.77,
#   4.35,
#   4.26,
#   4.09,
#   3.95,
#   3.85,
#   4.09,
#   3.56,
#   3.65,
#   3.69,
#   3.86,
#   3.66,
#   4.08,
#   3.94,
#   3.72,
#   4.29,
#   3.46],
#  'language_code': ['eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng',
#   'eng'],
#  'series': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'earliest_pub_date': [Timestamp('1992-03-19 00:00:00'),
#   Timestamp('1984-04-01 00:00:00'),
#   Timestamp('1992-10-08 00:00:00'),
#   Timestamp('2001-12-01 00:00:00'),
#   Timestamp('1980-03-01 00:00:00'),
#   Timestamp('1975-10-17 00:00:00'),
#   Timestamp('1979-09-06 00:00:00'),
#   Timestamp('1988-01-01 00:00:00'),
#   Timestamp('1997-10-23 00:00:00'),
#   Timestamp('1996-01-01 00:00:00'),
#   Timestamp('1998-09-01 00:00:00'),
#   Timestamp('1985-04-01 00:00:00'),
#   Timestamp('2000-09-19 00:00:00'),
#   Timestamp('1925-09-01 00:00:00'),
#   Timestamp('1954-09-01 00:00:00'),
#   Timestamp('1993-10-26 00:00:00'),
#   Timestamp('1994-12-19 00:00:00'),
#   Timestamp('2001-09-15 00:00:00'),
#   Timestamp('1995-12-17 00:00:00'),
#   Timestamp('1993-10-28 00:00:00'),
#   Timestamp('2001-04-10 00:00:00'),
#   Timestamp('1997-06-17 00:00:00'),
#   Timestamp('1993-03-18 00:00:00'),
#   Timestamp('1998-06-25 00:00:00'),
#   Timestamp('1998-05-02 00:00:00'),
#   Timestamp('1977-01-01 00:00:00'),
#   Timestamp('1980-07-01 00:00:00'),
#   Timestamp('1948-06-01 00:00:00'),
#   Timestamp('2003-04-08 00:00:00'),
#   Timestamp('1972-06-11 00:00:00'),
#   Timestamp('1986-05-12 00:00:00'),
#   Timestamp('1957-10-12 00:00:00'),
#   Timestamp('1993-03-17 00:00:00'),
#   Timestamp('1979-12-20 00:00:00'),
#   Timestamp('2001-01-01 00:00:00'),
#   Timestamp('2004-05-11 00:00:00'),
#   Timestamp('1984-12-01 00:00:00'),
#   Timestamp('1998-06-04 00:00:00'),
#   Timestamp('1997-05-09 00:00:00'),
#   Timestamp('2002-10-17 00:00:00'),
#   Timestamp('2000-09-28 00:00:00'),
#   Timestamp('1994-10-01 00:00:00'),
#   Timestamp('2001-05-01 00:00:00'),
#   Timestamp('1996-12-01 00:00:00'),
#   Timestamp('2003-05-06 00:00:00'),
#   Timestamp('1996-08-01 00:00:00'),
#   Timestamp('1991-05-01 00:00:00'),
#   Timestamp('1993-03-02 00:00:00'),
#   Timestamp('2000-03-30 00:00:00'),
#   Timestamp('2003-03-18 00:00:00'),
#   Timestamp('1995-10-24 00:00:00'),
#   Timestamp('1993-03-09 00:00:00'),
#   Timestamp('2003-02-27 00:00:00'),
#   Timestamp('1994-01-13 00:00:00'),
#   Timestamp('1984-09-17 00:00:00'),
#   Timestamp('1995-11-14 00:00:00'),
#   Timestamp('1992-09-15 00:00:00'),
#   Timestamp('2001-12-01 00:00:00'),
#   Timestamp('1987-09-01 00:00:00'),
#   Timestamp('2000-01-01 00:00:00'),
#   Timestamp('1994-05-26 00:00:00'),
#   Timestamp('1999-07-08 00:00:00'),
#   Timestamp('1990-06-16 00:00:00'),
#   Timestamp('2004-06-15 00:00:00'),
#   Timestamp('1982-03-25 00:00:00'),
#   Timestamp('2000-11-30 00:00:00'),
#   Timestamp('1984-03-01 00:00:00'),
#   Timestamp('2002-02-22 00:00:00'),
#   Timestamp('1975-08-28 00:00:00'),
#   Timestamp('2004-01-01 00:00:00'),
#   Timestamp('1994-03-31 00:00:00'),
#   Timestamp('1987-05-15 00:00:00'),
#   Timestamp('2003-07-28 00:00:00'),
#   Timestamp('1999-10-06 00:00:00'),
#   Timestamp('2001-05-01 00:00:00'),
#   Timestamp('2003-06-01 00:00:00'),
#   Timestamp('1999-10-01 00:00:00'),
#   Timestamp('2002-06-11 00:00:00'),
#   Timestamp('1994-01-01 00:00:00'),
#   Timestamp('2002-06-03 00:00:00'),
#   Timestamp('1995-09-03 00:00:00'),
#   Timestamp('2003-05-01 00:00:00'),
#   Timestamp('1970-07-30 00:00:00'),
#   Timestamp('1998-10-24 00:00:00'),
#   Timestamp('1970-02-01 00:00:00'),
#   Timestamp('2005-09-06 00:00:00'),
#   Timestamp('2005-01-25 00:00:00'),
#   Timestamp('2003-06-01 00:00:00'),
#   Timestamp('1995-12-04 00:00:00'),
#   Timestamp('2003-12-15 00:00:00'),
#   Timestamp('1998-10-03 00:00:00'),
#   Timestamp('1976-06-01 00:00:00'),
#   Timestamp('1988-08-12 00:00:00'),
#   Timestamp('2004-03-01 00:00:00'),
#   Timestamp('1999-10-01 00:00:00'),
#   Timestamp('1996-04-12 00:00:00'),
#   Timestamp('2003-03-25 00:00:00'),
#   Timestamp('1979-03-12 00:00:00'),
#   Timestamp('2005-01-11 00:00:00'),
#   Timestamp('1995-08-01 00:00:00'),
#   Timestamp('1993-12-01 00:00:00'),
#   Timestamp('2001-03-15 00:00:00'),
#   Timestamp('1978-01-01 00:00:00'),
#   Timestamp('2005-07-05 00:00:00'),
#   Timestamp('2000-09-12 00:00:00'),
#   Timestamp('1950-11-01 00:00:00'),
#   Timestamp('1962-01-11 00:00:00'),
#   Timestamp('2003-04-03 00:00:00'),
#   Timestamp('1993-11-17 00:00:00'),
#   Timestamp('2000-02-24 00:00:00'),
#   Timestamp('2002-08-01 00:00:00'),
#   Timestamp('1995-06-01 00:00:00'),
#   Timestamp('2005-12-07 00:00:00'),
#   Timestamp('1959-07-01 00:00:00'),
#   Timestamp('2006-10-10 00:00:00'),
#   Timestamp('2000-01-28 00:00:00'),
#   Timestamp('1998-05-04 00:00:00'),
#   Timestamp('1993-02-02 00:00:00'),
#   Timestamp('1999-10-15 00:00:00'),
#   Timestamp('2006-09-19 00:00:00'),
#   Timestamp('1998-06-01 00:00:00'),
#   Timestamp('1992-12-17 00:00:00'),
#   Timestamp('2000-02-03 00:00:00'),
#   Timestamp('2001-09-01 00:00:00'),
#   Timestamp('2005-04-12 00:00:00'),
#   Timestamp('2004-04-15 00:00:00'),
#   Timestamp('2004-05-01 00:00:00'),
#   Timestamp('1977-11-15 00:00:00'),
#   Timestamp('2005-05-01 00:00:00'),
#   Timestamp('2002-03-15 00:00:00'),
#   Timestamp('1984-11-30 00:00:00'),
#   Timestamp('1993-04-13 00:00:00'),
#   Timestamp('2002-02-26 00:00:00'),
#   Timestamp('1992-06-02 00:00:00'),
#   Timestamp('1996-02-17 00:00:00'),
#   Timestamp('1994-12-01 00:00:00'),
#   Timestamp('1991-02-13 00:00:00'),
#   Timestamp('1991-01-30 00:00:00'),
#   Timestamp('2001-01-16 00:00:00'),
#   Timestamp('2002-04-01 00:00:00'),
#   Timestamp('2002-06-04 00:00:00'),
#   Timestamp('2006-10-17 00:00:00'),
#   Timestamp('2006-10-09 00:00:00'),
#   Timestamp('1982-04-08 00:00:00'),
#   Timestamp('2001-06-15 00:00:00'),
#   Timestamp('2000-06-01 00:00:00'),
#   Timestamp('1991-03-01 00:00:00'),
#   Timestamp('2004-04-06 00:00:00'),
#   Timestamp('2004-06-08 00:00:00'),
#   Timestamp('2000-07-03 00:00:00'),
#   Timestamp('1989-01-13 00:00:00'),
#   Timestamp('1996-06-01 00:00:00'),
#   Timestamp('1989-12-27 00:00:00'),
#   Timestamp('2004-03-09 00:00:00'),
#   Timestamp('2006-01-24 00:00:00'),
#   Timestamp('1986-11-01 00:00:00'),
#   Timestamp('1996-11-01 00:00:00'),
#   Timestamp('2006-03-28 00:00:00'),
#   Timestamp('2004-06-03 00:00:00'),
#   Timestamp('1998-04-15 00:00:00'),
#   Timestamp('2002-02-08 00:00:00'),
#   Timestamp('1993-11-15 00:00:00'),
#   Timestamp('2003-05-06 00:00:00'),
#   Timestamp('2003-03-01 00:00:00'),
#   Timestamp('2002-07-01 00:00:00'),
#   Timestamp('1973-03-11 00:00:00'),
#   Timestamp('1989-05-01 00:00:00'),
#   Timestamp('2002-02-12 00:00:00'),
#   Timestamp('2005-07-12 00:00:00'),
#   Timestamp('2004-09-24 00:00:00'),
#   Timestamp('1994-03-31 00:00:00'),
#   Timestamp('1999-11-01 00:00:00'),
#   Timestamp('2000-11-16 00:00:00'),
#   Timestamp('2005-10-11 00:00:00'),
#   Timestamp('2001-04-24 00:00:00'),
#   Timestamp('1987-06-01 00:00:00'),
#   Timestamp('2000-08-31 00:00:00'),
#   Timestamp('1985-04-30 00:00:00'),
#   Timestamp('2000-07-18 00:00:00'),
#   Timestamp('2001-04-01 00:00:00'),
#   Timestamp('2000-05-02 00:00:00'),
#   Timestamp('1998-05-11 00:00:00'),
#   Timestamp('2005-03-18 00:00:00'),
#   Timestamp('2004-10-14 00:00:00'),
#   Timestamp('1994-12-31 00:00:00'),
#   Timestamp('2003-12-30 00:00:00'),
#   Timestamp('2001-04-10 00:00:00'),
#   Timestamp('2004-05-01 00:00:00'),
#   Timestamp('1989-07-06 00:00:00'),
#   Timestamp('2004-04-01 00:00:00'),
#   Timestamp('1983-10-01 00:00:00'),
#   Timestamp('2006-04-01 00:00:00'),
#   Timestamp('2006-08-29 00:00:00'),
#   Timestamp('2001-09-01 00:00:00'),
#   Timestamp('1994-10-20 00:00:00'),
#   Timestamp('2003-05-22 00:00:00'),
#   Timestamp('2004-09-15 00:00:00'),
#   Timestamp('1987-09-01 00:00:00'),
#   Timestamp('1998-07-16 00:00:00'),
#   Timestamp('1996-09-12 00:00:00'),
#   Timestamp('2002-05-28 00:00:00'),
#   Timestamp('2000-09-05 00:00:00'),
#   Timestamp('1998-03-16 00:00:00'),
#   Timestamp('2001-05-22 00:00:00'),
#   Timestamp('1978-07-12 00:00:00'),
#   Timestamp('2000-05-12 00:00:00'),
#   Timestamp('2001-01-01 00:00:00'),
#   Timestamp('1994-12-23 00:00:00'),
#   Timestamp('1998-01-23 00:00:00'),
#   Timestamp('2005-06-28 00:00:00'),
#   Timestamp('2003-05-27 00:00:00'),
#   Timestamp('1986-09-01 00:00:00'),
#   Timestamp('1984-05-01 00:00:00'),
#   Timestamp('2000-05-01 00:00:00'),
#   Timestamp('1993-03-18 00:00:00'),
#   Timestamp('1999-02-01 00:00:00'),
#   Timestamp('2004-10-01 00:00:00'),
#   Timestamp('1998-04-21 00:00:00'),
#   Timestamp('2003-04-03 00:00:00'),
#   Timestamp('2003-01-28 00:00:00'),
#   Timestamp('1984-10-01 00:00:00'),
#   Timestamp('2004-08-31 00:00:00'),
#   Timestamp('2005-07-18 00:00:00'),
#   Timestamp('1987-07-07 00:00:00'),
#   Timestamp('2000-09-01 00:00:00'),
#   Timestamp('1989-01-13 00:00:00'),
#   Timestamp('2004-02-02 00:00:00'),
#   Timestamp('1982-09-16 00:00:00'),
#   Timestamp('1982-02-01 00:00:00'),
#   Timestamp('1989-04-04 00:00:00'),
#   Timestamp('2002-06-11 00:00:00'),
#   Timestamp('2003-01-01 00:00:00'),
#   Timestamp('1954-09-12 00:00:00'),
#   Timestamp('2002-11-12 00:00:00'),
#   Timestamp('2004-07-22 00:00:00'),
#   Timestamp('1960-02-28 00:00:00'),
#   Timestamp('2003-02-04 00:00:00'),
#   Timestamp('2002-09-04 00:00:00'),
#   Timestamp('2000-03-30 00:00:00'),
#   Timestamp('2001-07-19 00:00:00'),
#   Timestamp('1979-06-01 00:00:00'),
#   Timestamp('1983-02-01 00:00:00'),
#   Timestamp('2005-11-01 00:00:00'),
#   Timestamp('2004-02-24 00:00:00'),
#   Timestamp('2005-05-01 00:00:00'),
#   Timestamp('1977-11-24 00:00:00'),
#   Timestamp('2003-07-01 00:00:00'),
#   Timestamp('2003-10-02 00:00:00'),
#   Timestamp('1988-10-01 00:00:00'),
#   Timestamp('1997-04-03 00:00:00'),
#   Timestamp('2002-07-09 00:00:00'),
#   Timestamp('1968-08-01 00:00:00'),
#   Timestamp('2003-06-05 00:00:00'),
#   Timestamp('2001-09-11 00:00:00'),
#   Timestamp('2005-03-01 00:00:00'),
#   Timestamp('2001-05-01 00:00:00'),
#   Timestamp('2005-11-01 00:00:00'),
#   Timestamp('1997-10-28 00:00:00'),
#   Timestamp('2001-11-14 00:00:00'),
#   Timestamp('2005-01-01 00:00:00'),
#   Timestamp('1998-09-01 00:00:00'),
#   Timestamp('2005-03-18 00:00:00'),
#   Timestamp('2006-10-17 00:00:00'),
#   Timestamp('2005-11-01 00:00:00'),
#   Timestamp('1994-12-01 00:00:00'),
#   Timestamp('2006-06-23 00:00:00'),
#   Timestamp('1982-10-22 00:00:00'),
#   Timestamp('1994-01-01 00:00:00'),
#   Timestamp('2006-08-08 00:00:00'),
#   Timestamp('2001-02-08 00:00:00'),
#   Timestamp('1993-10-05 00:00:00'),
#   Timestamp('2004-09-17 00:00:00'),
#   Timestamp('1993-09-16 00:00:00'),
#   Timestamp('2003-09-05 00:00:00'),
#   Timestamp('2002-11-26 00:00:00'),
#   Timestamp('1999-06-02 00:00:00'),
#   Timestamp('1996-06-14 00:00:00'),
#   Timestamp('2004-09-04 00:00:00'),
#   Timestamp('2001-02-01 00:00:00'),
#   Timestamp('2001-09-08 00:00:00'),
#   Timestamp('2001-04-30 00:00:00'),
#   Timestamp('2002-03-04 00:00:00'),
#   Timestamp('1961-12-01 00:00:00'),
#   Timestamp('2000-11-20 00:00:00'),
#   Timestamp('1990-11-01 00:00:00'),
#   Timestamp('2001-09-20 00:00:00'),
#   Timestamp('2001-04-21 00:00:00'),
#   Timestamp('2005-01-26 00:00:00'),
#   Timestamp('1998-10-16 00:00:00'),
#   Timestamp('2003-11-17 00:00:00'),
#   Timestamp('2003-09-23 00:00:00'),
#   Timestamp('2003-01-28 00:00:00'),
#   Timestamp('2004-04-01 00:00:00'),
#   Timestamp('2001-03-01 00:00:00'),
#   Timestamp('1985-01-01 00:00:00'),
#   Timestamp('2005-02-08 00:00:00'),
#   Timestamp('2001-03-17 00:00:00'),
#   Timestamp('1998-09-17 00:00:00'),
#   Timestamp('1995-06-24 00:00:00'),
#   Timestamp('1999-10-06 00:00:00'),
#   Timestamp('1992-11-12 00:00:00'),
#   Timestamp('1998-09-03 00:00:00'),
#   Timestamp('1979-02-01 00:00:00'),
#   Timestamp('1991-12-12 00:00:00'),
#   Timestamp('2003-12-14 00:00:00'),
#   Timestamp('2000-01-01 00:00:00'),
#   Timestamp('2003-01-16 00:00:00'),
#   Timestamp('2004-11-25 00:00:00'),
#   Timestamp('1999-02-16 00:00:00'),
#   Timestamp('2002-07-01 00:00:00'),
#   Timestamp('2004-09-30 00:00:00'),
#   Timestamp('2003-06-16 00:00:00'),
#   Timestamp('2002-03-06 00:00:00'),
#   Timestamp('2000-02-21 00:00:00'),
#   Timestamp('2000-06-30 00:00:00'),
#   Timestamp('2000-05-02 00:00:00'),
#   Timestamp('1990-12-01 00:00:00'),
#   Timestamp('1994-08-09 00:00:00'),
#   Timestamp('2002-09-29 00:00:00'),
#   Timestamp('1999-09-01 00:00:00'),
#   Timestamp('1996-09-01 00:00:00'),
#   Timestamp('1999-05-25 00:00:00'),
#   Timestamp('2004-01-14 00:00:00'),
#   Timestamp('2006-04-05 00:00:00'),
#   Timestamp('2005-11-01 00:00:00'),
#   Timestamp('2004-11-23 00:00:00'),
#   Timestamp('1963-11-01 00:00:00'),
#   Timestamp('2005-06-02 00:00:00'),
#   Timestamp('2001-01-01 00:00:00'),
#   Timestamp('2000-01-27 00:00:00'),
#   Timestamp('1992-09-05 00:00:00'),
#   Timestamp('1993-08-01 00:00:00'),
#   Timestamp('1996-08-06 00:00:00'),
#   Timestamp('2000-04-27 00:00:00'),
#   Timestamp('2003-03-06 00:00:00'),
#   Timestamp('2002-12-31 00:00:00'),
#   Timestamp('2002-12-02 00:00:00'),
#   Timestamp('2006-01-06 00:00:00'),
#   Timestamp('2005-08-01 00:00:00'),
#   Timestamp('2006-05-23 00:00:00'),
#   Timestamp('2005-10-04 00:00:00'),
#   Timestamp('2003-03-23 00:00:00'),
#   Timestamp('1999-12-09 00:00:00'),
#   Timestamp('2002-06-10 00:00:00'),
#   Timestamp('1994-05-10 00:00:00'),
#   Timestamp('2001-02-13 00:00:00'),
#   Timestamp('1996-11-18 00:00:00'),
#   Timestamp('2006-09-12 00:00:00'),
#   Timestamp('2004-05-03 00:00:00'),
#   Timestamp('1976-11-18 00:00:00'),
#   Timestamp('2005-03-02 00:00:00'),
#   Timestamp('2004-06-01 00:00:00'),
#   Timestamp('2004-06-08 00:00:00'),
#   Timestamp('1983-06-01 00:00:00'),
#   Timestamp('1952-12-01 00:00:00'),
#   Timestamp('1993-06-12 00:00:00'),
#   Timestamp('1980-05-04 00:00:00'),
#   Timestamp('1965-03-01 00:00:00'),
#   Timestamp('2002-12-25 00:00:00'),
#   Timestamp('1992-04-07 00:00:00'),
# ...
#   Timestamp('2006-08-29 00:00:00'),
#   Timestamp('1988-06-01 00:00:00'),
#   Timestamp('2006-09-01 00:00:00'),
#   Timestamp('2002-11-05 00:00:00'),
#   Timestamp('2005-01-25 00:00:00'),
#   Timestamp('1983-12-29 00:00:00'),
#   Timestamp('2006-05-01 00:00:00'),
#   Timestamp('2002-02-05 00:00:00'),
#   Timestamp('2003-05-27 00:00:00'),
#   Timestamp('2005-02-01 00:00:00'),
#   Timestamp('1993-11-01 00:00:00'),
#   Timestamp('2006-09-12 00:00:00'),
#   Timestamp('2004-10-17 00:00:00'),
#   Timestamp('1999-07-22 00:00:00'),
#   Timestamp('2004-10-01 00:00:00'),
#   Timestamp('2003-09-16 00:00:00'),
#   Timestamp('2004-10-07 00:00:00'),
#   Timestamp('2003-02-25 00:00:00'),
#   Timestamp('2000-08-15 00:00:00'),
#   Timestamp('1992-03-28 00:00:00'),
#   Timestamp('2006-01-17 00:00:00'),
#   Timestamp('2005-02-24 00:00:00'),
#   Timestamp('2006-11-14 00:00:00'),
#   Timestamp('1994-01-01 00:00:00'),
#   Timestamp('2005-08-02 00:00:00'),
#   Timestamp('2004-09-21 00:00:00'),
#   Timestamp('2002-08-27 00:00:00'),
#   Timestamp('2003-01-01 00:00:00'),
#   Timestamp('2006-01-06 00:00:00'),
#   Timestamp('1969-01-01 00:00:00'),
#   Timestamp('2007-09-01 00:00:00'),
#   Timestamp('2001-10-04 00:00:00'),
#   Timestamp('2006-06-16 00:00:00'),
#   Timestamp('2007-01-09 00:00:00'),
#   Timestamp('2006-11-07 00:00:00'),
#   Timestamp('2000-03-30 00:00:00'),
#   Timestamp('2005-09-01 00:00:00'),
#   Timestamp('2005-10-01 00:00:00'),
#   Timestamp('2006-10-17 00:00:00'),
#   Timestamp('2006-02-10 00:00:00'),
#   Timestamp('2006-12-08 00:00:00'),
#   Timestamp('2006-03-01 00:00:00'),
#   Timestamp('1995-09-15 00:00:00'),
#   Timestamp('2006-09-16 00:00:00'),
#   Timestamp('1982-12-31 00:00:00'),
#   Timestamp('1997-01-15 00:00:00'),
#   Timestamp('2007-04-01 00:00:00'),
#   Timestamp('2003-05-06 00:00:00'),
#   Timestamp('2002-06-11 00:00:00'),
#   Timestamp('2005-12-13 00:00:00'),
#   Timestamp('2006-05-02 00:00:00'),
#   Timestamp('2004-06-01 00:00:00'),
#   Timestamp('2006-12-05 00:00:00'),
#   Timestamp('2003-11-01 00:00:00'),
#   Timestamp('2000-06-01 00:00:00'),
#   Timestamp('2004-10-07 00:00:00'),
#   Timestamp('2001-03-05 00:00:00'),
#   Timestamp('2003-05-01 00:00:00'),
#   Timestamp('2002-03-12 00:00:00'),
#   Timestamp('2005-10-01 00:00:00'),
#   Timestamp('2005-01-17 00:00:00'),
#   Timestamp('2001-06-25 00:00:00'),
#   Timestamp('1998-12-01 00:00:00'),
#   Timestamp('2002-01-01 00:00:00'),
#   Timestamp('2004-11-09 00:00:00'),
#   Timestamp('2006-01-03 00:00:00'),
#   Timestamp('2001-09-20 00:00:00'),
#   Timestamp('2004-08-03 00:00:00'),
#   Timestamp('2005-09-02 00:00:00'),
#   Timestamp('2005-10-04 00:00:00'),
#   Timestamp('2005-11-01 00:00:00'),
#   Timestamp('2006-03-28 00:00:00'),
#   Timestamp('2003-04-17 00:00:00'),
#   Timestamp('2006-08-15 00:00:00'),
#   Timestamp('2002-01-01 00:00:00'),
#   Timestamp('1999-07-01 00:00:00'),
#   Timestamp('2006-09-15 00:00:00'),
#   Timestamp('2006-05-02 00:00:00'),
#   Timestamp('2003-06-23 00:00:00'),
#   Timestamp('2000-02-24 00:00:00'),
#   Timestamp('1993-10-01 00:00:00'),
#   Timestamp('1999-09-03 00:00:00'),
#   Timestamp('2004-12-21 00:00:00'),
#   Timestamp('2000-09-11 00:00:00'),
#   Timestamp('2005-08-25 00:00:00'),
#   Timestamp('2005-07-25 00:00:00'),
#   Timestamp('2005-11-01 00:00:00'),
#   Timestamp('2006-12-26 00:00:00'),
#   Timestamp('2005-09-27 00:00:00'),
#   Timestamp('2003-06-23 00:00:00'),
#   Timestamp('2006-09-01 00:00:00'),
#   Timestamp('2000-03-28 00:00:00'),
#   Timestamp('2004-09-24 00:00:00'),
#   Timestamp('2005-02-08 00:00:00'),
#   Timestamp('1991-07-01 00:00:00'),
#   Timestamp('2004-03-02 00:00:00'),
#   Timestamp('2004-02-03 00:00:00'),
#   Timestamp('2004-06-22 00:00:00'),
#   Timestamp('2005-04-26 00:00:00'),
#   Timestamp('2001-04-09 00:00:00'),
#   Timestamp('2006-02-07 00:00:00'),
#   Timestamp('2019-08-06 00:00:00'),
#   Timestamp('2006-09-05 00:00:00'),
#   Timestamp('2006-05-30 00:00:00'),
#   Timestamp('2003-04-10 00:00:00'),
#   Timestamp('2006-06-01 00:00:00'),
#   Timestamp('2006-03-28 00:00:00'),
#   Timestamp('2000-02-05 00:00:00'),
#   Timestamp('2005-07-06 00:00:00'),
#   Timestamp('2002-02-10 00:00:00'),
#   Timestamp('1996-09-05 00:00:00'),
#   Timestamp('2005-09-06 00:00:00'),
#   Timestamp('2006-05-30 00:00:00'),
#   Timestamp('2006-10-01 00:00:00'),
#   Timestamp('2002-12-03 00:00:00'),
#   Timestamp('2006-03-01 00:00:00'),
#   Timestamp('2006-04-12 00:00:00'),
#   Timestamp('2007-04-03 00:00:00'),
#   Timestamp('2007-02-13 00:00:00'),
#   Timestamp('2004-04-05 00:00:00'),
#   Timestamp('2000-09-12 00:00:00'),
#   Timestamp('2003-05-01 00:00:00'),
#   Timestamp('2006-10-26 00:00:00'),
#   Timestamp('2006-02-14 00:00:00'),
#   Timestamp('1997-06-23 00:00:00'),
#   Timestamp('2012-01-01 00:00:00'),
#   Timestamp('2004-10-15 00:00:00'),
#   Timestamp('2006-07-04 00:00:00'),
#   Timestamp('2006-03-14 00:00:00'),
#   Timestamp('2005-04-01 00:00:00'),
#   Timestamp('2005-04-12 00:00:00'),
#   Timestamp('2008-07-22 00:00:00'),
#   Timestamp('2004-09-17 00:00:00'),
#   Timestamp('2006-11-14 00:00:00'),
#   Timestamp('2002-06-25 00:00:00'),
#   Timestamp('1989-11-07 00:00:00'),
#   Timestamp('2004-11-01 00:00:00'),
#   Timestamp('2004-06-08 00:00:00'),
#   Timestamp('2004-12-28 00:00:00'),
#   Timestamp('1990-10-07 00:00:00'),
#   Timestamp('2006-10-24 00:00:00'),
#   Timestamp('2005-11-01 00:00:00'),
#   Timestamp('2004-10-01 00:00:00'),
#   Timestamp('2006-10-28 00:00:00'),
#   Timestamp('2000-11-02 00:00:00'),
#   Timestamp('2007-03-06 00:00:00'),
#   Timestamp('2004-02-01 00:00:00'),
#   Timestamp('2005-03-30 00:00:00'),
#   Timestamp('2007-04-05 00:00:00'),
#   Timestamp('2002-05-07 00:00:00'),
#   Timestamp('2005-11-01 00:00:00'),
#   Timestamp('2005-09-13 00:00:00'),
#   Timestamp('2004-01-16 00:00:00'),
#   Timestamp('2006-02-24 00:00:00'),
#   Timestamp('2003-04-29 00:00:00'),
#   Timestamp('1994-03-01 00:00:00'),
#   Timestamp('2005-08-01 00:00:00'),
#   Timestamp('2001-04-26 00:00:00'),
#   Timestamp('2006-10-02 00:00:00'),
#   Timestamp('2006-10-31 00:00:00'),
#   Timestamp('2008-07-01 00:00:00'),
#   Timestamp('2005-12-03 00:00:00'),
#   Timestamp('1997-04-12 00:00:00'),
#   Timestamp('2003-08-26 00:00:00'),
#   Timestamp('2005-10-01 00:00:00'),
#   Timestamp('1988-08-01 00:00:00'),
#   Timestamp('2001-09-11 00:00:00'),
#   Timestamp('2006-06-06 00:00:00'),
#   Timestamp('2005-05-26 00:00:00'),
#   Timestamp('2005-08-30 00:00:00'),
#   Timestamp('2007-01-10 00:00:00'),
#   Timestamp('2003-02-26 00:00:00'),
#   Timestamp('1988-09-23 00:00:00'),
#   Timestamp('2004-09-10 00:00:00'),
#   Timestamp('2006-10-05 00:00:00'),
#   Timestamp('2002-06-18 00:00:00'),
#   Timestamp('2004-10-01 00:00:00'),
#   Timestamp('2005-04-19 00:00:00'),
#   Timestamp('2005-09-13 00:00:00'),
#   Timestamp('1997-01-15 00:00:00'),
#   Timestamp('2004-10-05 00:00:00'),
#   Timestamp('2006-08-01 00:00:00'),
#   Timestamp('2004-09-21 00:00:00'),
#   Timestamp('2012-04-03 00:00:00'),
#   Timestamp('2006-05-30 00:00:00'),
#   Timestamp('2001-06-15 00:00:00'),
#   Timestamp('2003-11-17 00:00:00'),
#   Timestamp('2005-03-01 00:00:00'),
#   Timestamp('2004-10-07 00:00:00'),
#   Timestamp('1999-09-06 00:00:00'),
#   Timestamp('2001-08-07 00:00:00'),
#   Timestamp('2006-11-25 00:00:00'),
#   Timestamp('2009-03-04 00:00:00'),
#   Timestamp('1983-11-01 00:00:00'),
#   Timestamp('2006-05-02 00:00:00'),
#   Timestamp('2005-07-26 00:00:00'),
#   Timestamp('1994-08-15 00:00:00'),
#   Timestamp('2005-10-25 00:00:00'),
#   Timestamp('2007-05-29 00:00:00'),
#   Timestamp('2006-01-16 00:00:00'),
#   Timestamp('1978-06-12 00:00:00'),
#   Timestamp('2003-09-25 00:00:00'),
#   Timestamp('2005-02-01 00:00:00'),
#   Timestamp('2006-09-30 00:00:00'),
#   Timestamp('2007-08-21 00:00:00'),
#   Timestamp('2004-04-05 00:00:00'),
#   Timestamp('2006-03-28 00:00:00'),
#   Timestamp('2002-09-02 00:00:00'),
#   Timestamp('2005-05-01 00:00:00'),
#   Timestamp('2007-02-01 00:00:00'),
#   Timestamp('2006-09-05 00:00:00'),
#   Timestamp('2006-07-25 00:00:00'),
#   Timestamp('2004-10-07 00:00:00'),
#   Timestamp('2007-01-13 00:00:00'),
#   Timestamp('2006-12-01 00:00:00'),
#   Timestamp('2001-04-03 00:00:00'),
#   Timestamp('1998-02-02 00:00:00'),
#   Timestamp('2005-08-23 00:00:00'),
#   Timestamp('2007-08-28 00:00:00'),
#   Timestamp('2006-12-28 00:00:00'),
#   Timestamp('2003-08-01 00:00:00'),
#   Timestamp('2002-12-19 00:00:00'),
#   Timestamp('2008-02-01 00:00:00'),
#   Timestamp('2003-07-15 00:00:00'),
#   Timestamp('2004-01-31 00:00:00'),
#   Timestamp('2005-05-01 00:00:00'),
#   Timestamp('2001-05-03 00:00:00'),
#   Timestamp('2006-12-26 00:00:00'),
#   Timestamp('2005-02-01 00:00:00'),
#   Timestamp('2006-10-17 00:00:00'),
#   Timestamp('2006-09-01 00:00:00'),
#   Timestamp('2006-02-28 00:00:00'),
#   Timestamp('2005-04-04 00:00:00'),
#   Timestamp('2003-02-27 00:00:00'),
#   Timestamp('1998-08-06 00:00:00'),
#   Timestamp('1999-12-26 00:00:00'),
#   Timestamp('2007-06-01 00:00:00')],
#  'ratings_count': [295539,
#   197381,
#   766867,
#   141751,
#   196135,
#   85852,
#   6335,
#   763930,
#   1895075,
#   11271,
#   768872,
#   594633,
#   617128,
#   13600,
#   35540,
#   8429,
#   3082,
#   326098,
#   2539,
#   1301147,
#   166666,
#   1420001,
#   2544,
#   214391,
#   285,
#   70207,
#   980229,
#   76806,
#   97482,
#   5905,
#   786667,
#   324762,
#   116400,
#   43313,
#   5648,
#   196,
#   5247,
#   1587760,
#   156708,
#   139558,
#   55269,
#   9406,
#   56620,
#   24113,
#   550119,
#   138645,
#   12107,
#   499456,
#   287500,
#   1686222,
#   13034,
#   22740,
#   108942,
#   15982,
#   14351,
#   21664,
#   111068,
#   611760,
#   52716,
#   1480438,
#   2467,
#   48,
#   89478,
#   30212,
#   17522,
#   107918,
#   7531,
#   4161,
#   9996,
#   273611,
#   984,
#   166012,
#   2425666,
#   364,
#   284884,
#   12797,
#   277047,
#   657385,
#   9626,
#   41781,
#   22358,
#   322533,
#   169866,
#   60132,
#   30699,
#   62806,
#   103,
#   236058,
#   8567,
#   670,
#   103726,
#   54515,
#   26433,
#   3750,
#   620921,
#   40720,
#   108625,
#   166796,
#   442593,
#   89831,
#   74286,
#   92597,
#   330008,
#   11492,
#   191330,
#   62585,
#   516,
#   2068,
#   42147,
#   9334,
#   58465,
#   10389,
#   19936,
#   2037566,
#   39535,
#   5466,
#   314560,
#   2506,
#   448230,
#   3816,
#   541976,
#   2603,
#   7329,
#   2443,
#   382146,
#   1071510,
#   8333,
#   921,
#   78510,
#   79269,
#   617,
#   1573,
#   242476,
#   8015,
#   1239,
#   81441,
#   9026,
#   48123,
#   5400,
#   19315,
#   26840,
#   7642,
#   36507,
#   87827,
#   3181,
#   4597,
#   4,
#   1569,
#   282705,
#   12905,
#   4902,
#   247725,
#   4630,
#   986800,
#   2062,
#   3060,
#   1134,
#   15054,
#   481,
#   12258,
#   13093,
#   136474,
#   10125,
#   209422,
#   64424,
#   11291,
#   324507,
#   46773,
#   3206,
#   3380,
#   2052,
#   2228,
#   30,
#   2150,
#   79016,
#   46391,
#   78989,
#   3503,
#   66673,
#   11227,
#   25127,
#   1269,
#   4227,
#   103,
#   148125,
#   934,
#   140669,
#   2342726,
#   4076,
#   78258,
#   127836,
#   641062,
#   24009,
#   27365,
#   79029,
#   10076,
#   892,
#   75624,
#   16607,
#   3845,
#   39797,
#   17108,
#   19348,
#   28841,
#   792,
#   56559,
#   636,
#   2326,
#   5403,
#   25868,
#   30968,
#   19125,
#   382566,
#   304896,
#   380,
#   204243,
#   669097,
#   13867,
#   498,
#   553,
#   364,
#   147180,
#   245762,
#   10391,
#   121561,
#   15857,
#   5425,
#   760,
#   464,
#   61136,
#   37379,
#   13458,
#   1548,
#   28393,
#   3418,
#   3688,
#   108877,
#   541430,
#   73935,
#   101032,
#   3480,
#   56,
#   808670,
#   359,
#   3175,
#   7800,
#   167360,
#   31043,
#   49017,
#   2320,
#   81339,
#   138,
#   300,
#   1849,
#   265,
#   186370,
#   24624,
#   1767,
#   29804,
#   18,
#   1260574,
#   1355,
#   628843,
#   237934,
#   3750,
#   2096903,
#   51484,
#   2184,
#   37936,
#   45898,
#   35731,
#   43164,
#   283320,
#   2130267,
#   21259,
#   2300296,
#   3532,
#   292,
#   109491,
#   3746,
#   196441,
#   16,
#   385,
#   1015,
#   148,
#   4675,
#   4276,
#   227386,
#   6289,
#   48253,
#   524302,
#   1046009,
#   6216,
#   7081,
#   59,
#   45642,
#   235,
#   22145,
#   1241,
#   98544,
#   145816,
#   6788,
#   1776,
#   53886,
#   3718,
#   31296,
#   265,
#   1203,
#   3620,
#   514,
#   33658,
#   101885,
#   328,
#   1160,
#   53,
#   718,
#   15588,
#   40258,
#   68341,
#   35588,
#   273640,
#   172386,
#   94586,
#   38320,
#   9803,
#   220730,
#   97244,
#   4290,
#   120302,
#   533,
#   656,
#   517,
#   7121,
#   135653,
#   4219,
#   3623,
#   7534,
#   1766864,
#   22235,
#   10506,
#   123414,
#   11337,
#   10907,
#   75103,
#   12056,
#   29630,
#   15563,
#   11030,
#   625981,
#   168215,
#   1203,
#   479439,
#   1477,
#   12533,
#   238682,
#   6996,
#   184913,
#   24128,
#   564,
#   1766,
#   111422,
#   110234,
#   2804,
#   6637,
#   44732,
#   2344,
#   4902,
#   7588,
#   805,
#   7045,
#   3416,
#   26392,
#   248910,
#   69212,
#   62032,
#   7744,
#   228,
#   12244,
#   1689,
#   22262,
#   30111,
#   30526,
#   12875,
#   1482,
#   106600,
#   16977,
#   1022,
#   14037,
#   15176,
#   29189,
#   416,
#   56251,
#   23665,
#   2101,
#   22,
#   2793,
#   213584,
#   3977,
#   11,
#   1291,
#   27378,
#   37083,
#   61879,
#   22745,
#   48014,
#   132105,
#   630,
#   109268,
#   28950,
#   575,
#   38964,
#   17687,
#   223228,
#   126073,
#   204824,
#   116,
#   1632141,
#   3261,
#   190696,
#   1294,
#   30082,
#   15,
#   2336,
#   39246,
#   829,
#   3580,
#   476248,
#   75404,
#   416,
#   9246,
#   337786,
#   247,
#   26929,
#   29066,
#   29,
#   4053,
#   63435,
#   14262,
#   20224,
#   6974,
#   21838,
#   188878,
#   21737,
#   28268,
#   76537,
#   7007,
#   56527,
#   38,
#   7141,
#   886,
#   11543,
#   59172,
#   209089,
#   1346,
#   3746,
#   105024,
#   23602,
#   14718,
#   1028],
#  'text_reviews_count': [3791,
#   7564,
#   7035,
#   9106,
#   3545,
#   826,
#   260,
#   17405,
#   14710,
#   662,
#   12086,
#   7931,
#   10713,
#   1401,
#   688,
#   360,
#   307,
#   7109,
#   212,
#   14801,
#   4889,
#   28972,
#   352,
#   6594,
#   39,
#   3318,
#   15348,
#   2847,
#   3125,
#   603,
#   15515,
#   15029,
#   2824,
#   779,
#   263,
#   40,
#   602,
#   23725,
#   2954,
#   2678,
#   1492,
#   305,
#   1700,
#   434,
#   11198,
#   2566,
#   1261,
#   11559,
#   13994,
#   36634,
#   733,
#   2748,
#   5347,
#   771,
#   314,
#   489,
#   4038,
#   7324,
#   2983,
#   18521,
#   183,
#   9,
#   1416,
#   2724,
#   1407,
#   6236,
#   135,
#   290,
#   571,
#   4293,
#   115,
#   4147,
#   22076,
#   40,
#   5657,
#   1774,
#   7376,
#   14861,
#   980,
#   748,
#   421,
#   8492,
#   2461,
#   2869,
#   560,
#   1333,
#   29,
#   5891,
#   431,
#   104,
#   2417,
#   1416,
#   1625,
#   372,
#   20861,
#   938,
#   3590,
#   4834,
#   13410,
#   2219,
#   1391,
#   3308,
#   4840,
#   1112,
#   4820,
#   1192,
#   49,
#   144,
#   1385,
#   883,
#   3405,
#   321,
#   1918,
#   26352,
#   874,
#   422,
#   15791,
#   214,
#   11913,
#   430,
#   11594,
#   147,
#   778,
#   388,
#   23240,
#   37262,
#   597,
#   56,
#   3783,
#   1433,
#   52,
#   127,
#   4530,
#   336,
#   104,
#   3521,
#   587,
#   1955,
#   474,
#   563,
#   2010,
#   1234,
#   1546,
#   4515,
#   258,
#   86,
#   0,
#   105,
#   9062,
#   196,
#   105,
#   6492,
#   359,
#   29654,
#   41,
#   167,
#   101,
#   1564,
#   53,
#   185,
#   927,
#   2014,
#   765,
#   3432,
#   2058,
#   222,
#   13071,
#   1673,
#   300,
#   67,
#   125,
#   110,
#   1,
#   222,
#   3556,
#   2563,
#   4854,
#   195,
#   1718,
#   672,
#   1177,
#   73,
#   154,
#   13,
#   4213,
#   52,
#   2580,
#   36465,
#   293,
#   3203,
#   2104,
#   21011,
#   1412,
#   1146,
#   1815,
#   642,
#   74,
#   2906,
#   1250,
#   211,
#   2816,
#   370,
#   1105,
#   1844,
#   92,
#   1213,
#   52,
#   232,
#   97,
#   737,
#   552,
#   1434,
#   6139,
#   6380,
#   33,
#   3714,
#   6888,
#   642,
#   20,
#   135,
#   78,
#   5949,
#   8956,
#   199,
#   2292,
#   350,
#   255,
#   29,
#   95,
#   1047,
#   853,
#   772,
#   195,
#   963,
#   245,
#   102,
#   2738,
#   19776,
#   1593,
#   8634,
#   427,
#   9,
#   46182,
#   27,
#   43,
#   51,
#   4714,
#   1747,
#   2831,
#   73,
#   2586,
#   22,
#   19,
#   177,
#   40,
#   9693,
#   765,
#   273,
#   272,
#   9,
#   21300,
#   179,
#   13039,
#   4176,
#   179,
#   27669,
#   1221,
#   112,
#   828,
#   1776,
#   1029,
#   820,
#   5030,
#   13791,
#   985,
#   34936,
#   210,
#   32,
#   2862,
#   347,
#   4550,
#   1,
#   37,
#   98,
#   20,
#   289,
#   480,
#   12767,
#   298,
#   772,
#   17087,
#   26448,
#   752,
#   647,
#   7,
#   1721,
#   20,
#   660,
#   119,
#   2828,
#   3387,
#   648,
#   140,
#   2542,
#   388,
#   2313,
#   28,
#   158,
#   238,
#   38,
#   2972,
#   1891,
#   45,
#   41,
#   5,
#   32,
#   224,
#   1231,
#   3423,
#   871,
#   10292,
#   4096,
#   4820,
#   1323,
#   391,
#   9635,
#   957,
#   357,
#   3155,
#   55,
#   117,
#   30,
#   491,
#   5787,
#   390,
#   394,
#   521,
#   47985,
#   745,
#   645,
#   9047,
#   744,
#   256,
#   1731,
#   308,
#   986,
#   112,
#   843,
#   18834,
#   6273,
#   96,
#   11519,
#   139,
#   629,
#   2746,
#   212,
#   4499,
#   609,
#   43,
#   182,
#   7344,
#   1298,
#   158,
#   832,
#   562,
#   93,
#   155,
#   384,
#   47,
#   40,
#   249,
#   957,
#   9433,
#   4564,
#   1992,
#   564,
#   19,
#   475,
#   44,
#   1465,
#   1310,
#   2377,
#   468,
#   70,
#   3701,
#   1445,
#   253,
#   251,
#   670,
#   657,
#   22,
#   2188,
#   507,
#   216,
#   3,
#   80,
#   5616,
#   397,
#   1,
#   161,
#   2684,
#   1032,
#   1623,
#   1404,
#   1270,
#   3306,
#   22,
#   2110,
#   1444,
#   40,
#   2454,
#   764,
#   11239,
#   3252,
#   8157,
#   10,
#   55919,
#   478,
#   6668,
#   111,
#   1341,
#   1,
#   315,
#   1077,
#   74,
#   286,
#   16473,
#   4494,
#   34,
#   483,
#   9970,
#   29,
#   1727,
#   1119,
#   1,
#   383,
#   3069,
#   882,
#   774,
#   713,
#   1011,
#   1579,
#   815,
#   198,
#   3415,
#   396,
#   1581,
#   3,
#   512,
#   87,
#   360,
#   3562,
#   5099,
#   34,
#   279,
#   3828,
#   829,
#   633,
#   137]}

# %%
consolidated_books_df = pd.DataFrame.from_dict(consolidated_books_dict)

# %%
consolidated_books_df
# Out:
#                                     title              author  average_rating  \
# 0                               The Iliad               Homer            3.86
# 1                  The Brothers Karamazov  Fyodor Dostoyevsky            4.32
# 2                             The Odyssey               Homer            3.76
# 3                           Anna Karenina         Leo Tolstoy            4.05
# 4                      Gulliver's Travels      Jonathan Swift            3.57
# ..                                    ...                 ...             ...
# 454        Fear and Loathing in Las Vegas  Hunter S. Thompson            4.08
# 455            Far From the Madding Crowd        Thomas Hardy            3.94
# 456                             Timequake   Kurt Vonnegut Jr.            3.72
# 457  The Gospel According to Jesus Christ       José Saramago            4.29
# 458                     The Little Friend         Donna Tartt            3.46
#
#     language_code  series earliest_pub_date latest_pub_date  ratings_count  \
# 0             eng   False        1992-03-19      2011-09-01         295539
# 1             eng   False        1984-04-01      2005-05-01         197381
# 2             eng   False        1992-10-08      2006-11-30         766867
# 3             eng   False        2001-12-01      2004-11-23         141751
# 4             eng   False        1980-03-01      2008-01-29         196135
# ..            ...     ...               ...             ...            ...
# 454           eng   False        1982-12-01      2005-04-04           3746
# 455           eng   False        2002-11-14      2003-02-27         105024
# 456           eng   False        1997-10-17      1998-08-06          23602
# 457           eng   False        1994-09-28      1999-12-26          14718
# 458           eng   False        2002-10-28      2007-06-01           1028
#
#      text_reviews_count
# 0                  3791
# 1                  7564
# 2                  7035
# 3                  9106
# 4                  3545
# ..                  ...
# 454                 279
# 455                3828
# 456                 829
# 457                 633
# 458                 137
#
# [459 rows x 9 columns]

# %%
print(len(consolidated_books_df))
# Out:
# 459

# %%
#code from https://medium.com/@harsz89/how-to-drop-rows-based-on-column-values-using-pandas-dataframe-38cf50e4c95a
# Get indexes where name column has values in title list
dupe_indices = []
for i in titles:
    title_df = goodread_copy_df[(goodread_copy_df.title == i)]
    indices_list = list(title_df.index.values)
    dupe_indices.append(goodread_copy_df[goodread_copy_df['title'] == i].index)

# %%
#https://stackoverflow.com/questions/952914/how-to-make-a-flat-list-out-of-list-of-lists
flattened_dupe_indices = []
for sublist in dupe_indices:
    for item in sublist:
        flattened_dupe_indices.append(item)

# %%
print(len(flattened_dupe_indices))
print(len(goodread_copy_df))
# Out:
# 1195
# 10539

# %%
# Delete these row indexes from dataFrame
goodread_copy_df = goodread_copy_df.drop(flattened_dupe_indices)

# %%
print(len(goodread_copy_df))
# Out:
# 9344

# %%
goodread_copy_df['latest_pub_date']=goodread_copy_df['publication_date']
goodread_copy_df=goodread_copy_df.rename(columns={'publication_date': 'earliest_pub_date'}, errors="raise")
goodread_copy_df
# Out:
#                                                    title  \
# 1      Harry Potter and the Order of the Phoenix (Har...
# 4      Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 5      Unauthorized Harry Potter Book Seven News: "Ha...
# 6           Harry Potter Collection (Harry Potter  #1-6)
# 7      The Ultimate Hitchhiker's Guide: Five Complete...
# ...                                                  ...
# 10534                               Shipwreck (Island I)
# 10535  The Carl Hiaasen Collection: Lucky You and Sic...
# 10536                          The Full Box (Full  #1-4)
# 10537  Stowaway and Milk Run: Two Unabridged Stories ...
# 10538  Treasury of American Tall Tales: Volume 1: Dav...
#
#                        author  average_rating language_code  ratings_count  \
# 1                J.K. Rowling            4.49           eng        2153167
# 4                J.K. Rowling            4.78           eng          41428
# 5      W. Frederick Zimmerman            3.74           eng             19
# 6                J.K. Rowling            4.73           eng          28242
# 7               Douglas Adams            4.38           eng           3628
# ...                       ...             ...           ...            ...
# 10534           Gordon Korman            3.80           eng            103
# 10535            Carl Hiaasen            4.32           eng             90
# 10536         Janet Evanovich            4.29           eng            101
# 10537      Mary Higgins Clark            3.49           eng             64
# 10538          David Bromberg            3.86           eng             36
#
#        text_reviews_count earliest_pub_date  series latest_pub_date
# 1                   29221        2004-09-01    True      2004-09-01
# 4                     164        2004-09-13    True      2004-09-13
# 5                       1        2005-04-26   False      2005-04-26
# 6                     808        2005-09-12    True      2005-09-12
# 7                     254        2005-11-01    True      2005-11-01
# ...                   ...               ...     ...             ...
# 10534                  14        2007-02-01   False      2007-02-01
# 10535                   5        2006-06-06   False      2006-06-06
# 10536                   3        2016-02-16    True      2016-02-16
# 10537                   2        1999-12-01   False      1999-12-01
# 10538                   9        2006-08-22   False      2006-08-22
#
# [9344 rows x 9 columns]

# %%
#creating column name list
col_names = list(consolidated_books_df.columns)

#reorder goodread_df columns
goodread_copy_df = goodread_copy_df[col_names]
goodread_copy_df.head()
# Out:
#                                                title                  author  \
# 1  Harry Potter and the Order of the Phoenix (Har...            J.K. Rowling
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...            J.K. Rowling
# 5  Unauthorized Harry Potter Book Seven News: "Ha...  W. Frederick Zimmerman
# 6       Harry Potter Collection (Harry Potter  #1-6)            J.K. Rowling
# 7  The Ultimate Hitchhiker's Guide: Five Complete...           Douglas Adams
#
#    average_rating language_code  series earliest_pub_date latest_pub_date  \
# 1            4.49           eng    True        2004-09-01      2004-09-01
# 4            4.78           eng    True        2004-09-13      2004-09-13
# 5            3.74           eng   False        2005-04-26      2005-04-26
# 6            4.73           eng    True        2005-09-12      2005-09-12
# 7            4.38           eng    True        2005-11-01      2005-11-01
#
#    ratings_count  text_reviews_count
# 1        2153167               29221
# 4          41428                 164
# 5             19                   1
# 6          28242                 808
# 7           3628                 254

# %%
goodread_consolidated_df = goodread_copy_df.append(consolidated_books_df)

# %%
goodread_consolidated_df = goodread_consolidated_df.reset_index(drop=True)
goodread_consolidated_df
# Out:
#                                                   title  \
# 0     Harry Potter and the Order of the Phoenix (Har...
# 1     Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 2     Unauthorized Harry Potter Book Seven News: "Ha...
# 3          Harry Potter Collection (Harry Potter  #1-6)
# 4     The Ultimate Hitchhiker's Guide: Five Complete...
# ...                                                 ...
# 9798                     Fear and Loathing in Las Vegas
# 9799                         Far From the Madding Crowd
# 9800                                          Timequake
# 9801               The Gospel According to Jesus Christ
# 9802                                  The Little Friend
#
#                       author  average_rating language_code  series  \
# 0               J.K. Rowling            4.49           eng    True
# 1               J.K. Rowling            4.78           eng    True
# 2     W. Frederick Zimmerman            3.74           eng   False
# 3               J.K. Rowling            4.73           eng    True
# 4              Douglas Adams            4.38           eng    True
# ...                      ...             ...           ...     ...
# 9798      Hunter S. Thompson            4.08           eng   False
# 9799            Thomas Hardy            3.94           eng   False
# 9800       Kurt Vonnegut Jr.            3.72           eng   False
# 9801           José Saramago            4.29           eng   False
# 9802             Donna Tartt            3.46           eng   False
#
#      earliest_pub_date latest_pub_date  ratings_count  text_reviews_count
# 0           2004-09-01      2004-09-01        2153167               29221
# 1           2004-09-13      2004-09-13          41428                 164
# 2           2005-04-26      2005-04-26             19                   1
# 3           2005-09-12      2005-09-12          28242                 808
# 4           2005-11-01      2005-11-01           3628                 254
# ...                ...             ...            ...                 ...
# 9798        1982-12-01      2005-04-04           3746                 279
# 9799        2002-11-14      2003-02-27         105024                3828
# 9800        1997-10-17      1998-08-06          23602                 829
# 9801        1994-09-28      1999-12-26          14718                 633
# 9802        2002-10-28      2007-06-01           1028                 137
#
# [9803 rows x 9 columns]

# %% [markdown]
# ### Questions to look into:

# %%
goodread_consolidated_df.sort_values(by='ratings_count', ascending=False)
# Out:
#                                                   title                author  \
# 8474                            Twilight (Twilight  #1)       Stephenie Meyer
# 1280                The Hobbit  or There and Back Again        J.R.R. Tolkien
# 1098                             The Catcher in the Rye         J.D. Salinger
# 9416               Angels & Demons (Robert Langdon  #1)             Dan Brown
# 9531  Harry Potter and the Prisoner of Azkaban (Harr...          J.K. Rowling
# ...                                                 ...                   ...
# 1270                                       V.S. Naipaul      Bruce Alvin King
# 542   Melville and the politics of identity: From *K...        Julian Markels
# 2742  Brodie's notes on Aldous Huxley's brave new world        Graham Handley
# 4572             The Best American Mystery Stories 2002          James Ellroy
# 8622                                   Mission Possible  Kenneth H. Blanchard
#
#       average_rating language_code  series earliest_pub_date latest_pub_date  \
# 8474            3.59           eng    True        2006-09-06      2006-09-06
# 1280            4.27           eng   False        2002-08-15      2002-08-15
# 1098            3.80           eng   False        2001-01-30      2001-01-30
# 9416            3.89           eng    True        2003-07-28      2006-04-01
# 9531            4.56           eng    True        2004-05-01      2008-07-01
# ...              ...           ...     ...               ...             ...
# 1270            2.00           eng   False        2003-10-10      2003-10-10
# 542             3.33           eng   False        1993-07-01      1993-07-01
# 2742            0.00           eng   False        1992-08-20      1992-08-20
# 4572            3.58           eng   False        2002-10-15      2002-10-15
# 8622            3.44           eng   False        1999-04-30      1999-04-30
#
#       ratings_count  text_reviews_count
# 8474        4597666               94265
# 1280        2530894               32871
# 1098        2457092               43499
# 9416        2425666               22076
# 9531        2342726               36465
# ...             ...                 ...
# 1270              0                   0
# 542               0                   0
# 2742              0                   0
# 4572              0                   0
# 8622              0                   0
#
# [9803 rows x 9 columns]

# %%
most_ratings_slice = goodread_consolidated_df.sort_values(by='ratings_count', ascending=False).head(20)
most_ratings_slice = most_ratings_slice.reset_index(drop=True)

# %%
most_ratings_slice
# Out:
#                                                 title               author  \
# 0                             Twilight (Twilight  #1)      Stephenie Meyer
# 1                 The Hobbit  or There and Back Again       J.R.R. Tolkien
# 2                              The Catcher in the Rye        J.D. Salinger
# 3                Angels & Demons (Robert Langdon  #1)            Dan Brown
# 4   Harry Potter and the Prisoner of Azkaban (Harr...         J.K. Rowling
# 5   Harry Potter and the Chamber of Secrets (Harry...         J.K. Rowling
# 6   Harry Potter and the Order of the Phoenix (Har...         J.K. Rowling
# 7   The Fellowship of the Ring (The Lord of the Ri...       J.R.R. Tolkien
# 8                                         Animal Farm        George Orwell
# 9   Harry Potter and the Half-Blood Prince (Harry ...         J.K. Rowling
# 10                                  Lord of the Flies      William Golding
# 11                                   Romeo and Juliet  William Shakespeare
# 12  The Lightning Thief (Percy Jackson and the Oly...         Rick Riordan
# 13                                    Of Mice and Men       John Steinbeck
# 14             The Da Vinci Code (Robert Langdon  #2)            Dan Brown
# 15                                      The Alchemist         Paulo Coelho
# 16                                Memoirs of a Geisha        Arthur Golden
# 17                          The Giver (The Giver  #1)           Lois Lowry
# 18                                     The Book Thief         Markus Zusak
# 19                                       Little Women    Louisa May Alcott
#
#     average_rating language_code  series earliest_pub_date latest_pub_date  \
# 0             3.59           eng    True        2006-09-06      2006-09-06
# 1             4.27           eng   False        2002-08-15      2002-08-15
# 2             3.80           eng   False        2001-01-30      2001-01-30
# 3             3.89           eng    True        2003-07-28      2006-04-01
# 4             4.56           eng    True        2004-05-01      2008-07-01
# 5             4.42           eng    True        1999-06-02      2003-11-01
# 6             4.49           eng    True        2004-09-01      2004-09-01
# 7             4.36           eng    True        2003-09-05      2004-06-01
# 8             3.93           eng   False        2003-05-06      2003-05-06
# 9             4.57           eng    True        2006-06-23      2006-09-16
# 10            3.68           eng   False        1959-07-01      2005-10-11
# 11            3.74           eng   False        1997-10-23      2012-07-15
# 12            4.25           eng    True        2006-01-06      2006-03-01
# 13            3.87           eng   False        2002-01-08      2002-01-08
# 14            3.84           eng    True        2003-03-18      2006-03-28
# 15            3.86           eng   False        1993-05-01      2006-05-02
# 16            4.11           eng   False        1998-06-04      2005-12-01
# 17            4.13           eng    True        2006-01-24      2006-01-24
# 18            4.37           eng   False        2006-03-14      2006-03-14
# 19            4.07           eng   False        2000-01-01      2004-04-06
#
#     ratings_count  text_reviews_count
# 0         4597666               94265
# 1         2530894               32871
# 2         2457092               43499
# 3         2425666               22076
# 4         2342726               36465
# 5         2300296               34936
# 6         2153167               29221
# 7         2130267               13791
# 8         2111750               29677
# 9         2096903               27669
# 10        2037566               26352
# 11        1895075               14710
# 12        1766864               47985
# 13        1755253               25554
# 14        1686222               36634
# 15        1632141               55919
# 16        1587760               23725
# 17        1585589               56604
# 18        1516367               86881
# 19        1480438               18521

# %%
most_ratings_slice['gender'] = ['cis woman', 'cis man', 'cis man', 'cis man', 'cis woman', 'cis woman', 'cis woman',
                                'cis man', 'cis man', 'cis woman', 'cis man', 'cis man', 'cis man','cis man',  
                                'cis man', 'cis man', 'cis man','cis woman', 'cis man', 'cis woman']
most_ratings_slice['skin_color'] = 'white'

# %%
most_ratings_slice
# Out:
#                                                 title               author  \
# 0                             Twilight (Twilight  #1)      Stephenie Meyer
# 1                 The Hobbit  or There and Back Again       J.R.R. Tolkien
# 2                              The Catcher in the Rye        J.D. Salinger
# 3                Angels & Demons (Robert Langdon  #1)            Dan Brown
# 4   Harry Potter and the Prisoner of Azkaban (Harr...         J.K. Rowling
# 5   Harry Potter and the Chamber of Secrets (Harry...         J.K. Rowling
# 6   Harry Potter and the Order of the Phoenix (Har...         J.K. Rowling
# 7   The Fellowship of the Ring (The Lord of the Ri...       J.R.R. Tolkien
# 8                                         Animal Farm        George Orwell
# 9   Harry Potter and the Half-Blood Prince (Harry ...         J.K. Rowling
# 10                                  Lord of the Flies      William Golding
# 11                                   Romeo and Juliet  William Shakespeare
# 12  The Lightning Thief (Percy Jackson and the Oly...         Rick Riordan
# 13                                    Of Mice and Men       John Steinbeck
# 14             The Da Vinci Code (Robert Langdon  #2)            Dan Brown
# 15                                      The Alchemist         Paulo Coelho
# 16                                Memoirs of a Geisha        Arthur Golden
# 17                          The Giver (The Giver  #1)           Lois Lowry
# 18                                     The Book Thief         Markus Zusak
# 19                                       Little Women    Louisa May Alcott
#
#     average_rating language_code  series earliest_pub_date latest_pub_date  \
# 0             3.59           eng    True        2006-09-06      2006-09-06
# 1             4.27           eng   False        2002-08-15      2002-08-15
# 2             3.80           eng   False        2001-01-30      2001-01-30
# 3             3.89           eng    True        2003-07-28      2006-04-01
# 4             4.56           eng    True        2004-05-01      2008-07-01
# 5             4.42           eng    True        1999-06-02      2003-11-01
# 6             4.49           eng    True        2004-09-01      2004-09-01
# 7             4.36           eng    True        2003-09-05      2004-06-01
# 8             3.93           eng   False        2003-05-06      2003-05-06
# 9             4.57           eng    True        2006-06-23      2006-09-16
# 10            3.68           eng   False        1959-07-01      2005-10-11
# 11            3.74           eng   False        1997-10-23      2012-07-15
# 12            4.25           eng    True        2006-01-06      2006-03-01
# 13            3.87           eng   False        2002-01-08      2002-01-08
# 14            3.84           eng    True        2003-03-18      2006-03-28
# 15            3.86           eng   False        1993-05-01      2006-05-02
# 16            4.11           eng   False        1998-06-04      2005-12-01
# 17            4.13           eng    True        2006-01-24      2006-01-24
# 18            4.37           eng   False        2006-03-14      2006-03-14
# 19            4.07           eng   False        2000-01-01      2004-04-06
#
#     ratings_count  text_reviews_count     gender skin_color
# 0         4597666               94265  cis woman      white
# 1         2530894               32871    cis man      white
# 2         2457092               43499    cis man      white
# 3         2425666               22076    cis man      white
# 4         2342726               36465  cis woman      white
# 5         2300296               34936  cis woman      white
# 6         2153167               29221  cis woman      white
# 7         2130267               13791    cis man      white
# 8         2111750               29677    cis man      white
# 9         2096903               27669  cis woman      white
# 10        2037566               26352    cis man      white
# 11        1895075               14710    cis man      white
# 12        1766864               47985    cis man      white
# 13        1755253               25554    cis man      white
# 14        1686222               36634    cis man      white
# 15        1632141               55919    cis man      white
# 16        1587760               23725    cis man      white
# 17        1585589               56604  cis woman      white
# 18        1516367               86881    cis man      white
# 19        1480438               18521  cis woman      white

# %% [markdown]
# #### What gender of the author breakdown in the top 20 most-rated books vs the bottom 20 least-rated books?

# %% [markdown]
# #### What is the skin color breakdown in the top 20 most-rated books vs the bottom 20 least-rated books?

# %%
most_ratings_slice['author']
# Out:
# 0         Stephenie Meyer
# 1          J.R.R. Tolkien
# 2           J.D. Salinger
# 3               Dan Brown
# 4            J.K. Rowling
# 5            J.K. Rowling
# 6            J.K. Rowling
# 7          J.R.R. Tolkien
# 8           George Orwell
# 9            J.K. Rowling
# 10        William Golding
# 11    William Shakespeare
# 12           Rick Riordan
# 13         John Steinbeck
# 14              Dan Brown
# 15           Paulo Coelho
# 16          Arthur Golden
# 17             Lois Lowry
# 18           Markus Zusak
# 19      Louisa May Alcott
# Name: author, dtype: object

# %%
gender_sum = most_ratings_slice['gender'].value_counts()
gender_sum

fig = plt.figure(figsize=(12,7))
#code taken from https://www.dataforeverybody.com/matplotlib-seaborn-pie-charts/
gender_sum.plot.pie(autopct="%.f%%");
plt.savefig('gender_sum_pie.png')

# %%
skin_color = most_ratings_slice['skin_color'].value_counts()
skin_color

fig = plt.figure(figsize=(12,7))
skin_color.plot.pie(autopct="%.f%%", labeldistance=-1.1);
plt.savefig('skin_color_pie.png')

# %% [markdown]
# #### What is the series/not-a-series breakdown in the top 20 most-rated books vs the bottom 20 least-rated books?

# %%
#update series column to be 'Part of Series', 'In Same Universe', 'Solo Story'
most_ratings_slice.series = most_ratings_slice.series.replace({True: 'Part of Series', False:'Solo Story'})
most_ratings_slice.series.iloc[1] = most_ratings_slice.series.iloc[1].replace('Solo Story', 'In Same Universe')
most_ratings_slice.series.iloc[19] = most_ratings_slice.series.iloc[19].replace('Solo Story', 'In Same Universe')
# Out:
# /Users/jbryant/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
most_ratings_slice['series']
# Out:
# 0       Part of Series
# 1     In Same Universe
# 2           Solo Story
# 3       Part of Series
# 4       Part of Series
# 5       Part of Series
# 6       Part of Series
# 7       Part of Series
# 8           Solo Story
# 9       Part of Series
# 10          Solo Story
# 11          Solo Story
# 12      Part of Series
# 13          Solo Story
# 14      Part of Series
# 15          Solo Story
# 16          Solo Story
# 17      Part of Series
# 18          Solo Story
# 19    In Same Universe
# Name: series, dtype: object

# %%
fig = plt.figure(figsize=(12,7))
sns.countplot(data = most_ratings_slice, x = 'series', color=sns.color_palette()[0])

plt.title('Top 20 Most Rated Book, Broken Down by Connectedness')
plt.xlabel('Connectedness')
plt.ylabel('Number of Books');
plt.savefig('connected_books_bar.png')

# %%
series_sum = most_ratings_slice['series'].value_counts()
series_sum

#code taken from https://www.dataforeverybody.com/matplotlib-seaborn-pie-charts/
fig = plt.figure(figsize=(12,7))
series_sum.plot.pie(autopct="%.f%%");
plt.title('Top 20 Most Rated Book, Broken Down by Connectedness')
plt.savefig('connected_books_pie.png')

# %% [markdown]
# #### What is the genre breakdown in the top 20 most-rated books vs the bottom 20 least-rated books?

# %%
most_ratings_slice['title']
# Out:
# 0                               Twilight (Twilight  #1)
# 1                   The Hobbit  or There and Back Again
# 2                                The Catcher in the Rye
# 3                  Angels & Demons (Robert Langdon  #1)
# 4     Harry Potter and the Prisoner of Azkaban (Harr...
# 5     Harry Potter and the Chamber of Secrets (Harry...
# 6     Harry Potter and the Order of the Phoenix (Har...
# 7     The Fellowship of the Ring (The Lord of the Ri...
# 8                                           Animal Farm
# 9     Harry Potter and the Half-Blood Prince (Harry ...
# 10                                    Lord of the Flies
# 11                                     Romeo and Juliet
# 12    The Lightning Thief (Percy Jackson and the Oly...
# 13                                      Of Mice and Men
# 14               The Da Vinci Code (Robert Langdon  #2)
# 15                                        The Alchemist
# 16                                  Memoirs of a Geisha
# 17                            The Giver (The Giver  #1)
# 18                                       The Book Thief
# 19                                         Little Women
# Name: title, dtype: object

# %% [markdown]
# It's all fiction!
# Genres for top 20 titles:
#     Twilight: Romance, fantasy, young adult fiction (source: https://en.wikipedia.org/wiki/Twilight_(novel_series))
#     The Hobbit: High fantasy, Juvenile fantasy (source: https://en.wikipedia.org/wiki/The_Hobbit)
#     The Catcher in the Rye: Realistic fiction, Coming-of-age fiction (source: Wikipedia)
#     Angels & Demons/DaVinci Code: Mystery, Detective fiction, Conspiracy fiction, Thriller (source: Wikipedia)
#     Harry Potter books: Fantasy, drama, young adult fiction, mystery, thriller, Bildungsroman (source: Wikipedia)
#     Fellowship of the Ring: Fantasy (source: Wikipedia)
#     Animal Farm: Political satire (source: Wikipedia)
#     Lord of the Flies: Allegorical novel (source: Wikipedia)
#     Romeo and Juliet: Shakespearean tragedy (source: Wikipedia)
#     The Lightning Thief: Fantasy, Young adult, Greek mythology (source: Wikipedia)
#     Of Mice and Men: social realism (https://www.sparknotes.com/lit/micemen/genre/)
#     The Alchemist: Novel, Drama, Quest, Fantasy Fiction, Adventure fiction (https://en.wikipedia.org/wiki/The_Alchemist_(novel))
#     Memoirs of a Geisha: historical fiction, romance (https://en.wikipedia.org/wiki/Memoirs_of_a_Geisha; https://www.goodreads.com/book/show/929.Memoirs_of_a_Geisha)
#     The Giver: Young adult fiction, Dystopian novel, Science fiction (source: https://en.wikipedia.org/wiki/The_Giver)
#     The Book Thief: Novel-Historical Fiction (https://en.wikipedia.org/wiki/The_Book_Thief)
#     Little Women: Coming of age, Bildungsroman (source: https://en.wikipedia.org/wiki/Little_Women)

# %%
most_ratings_slice['category'] = 'fiction'
most_ratings_slice['genre'] = ['romance', 'fantasy', 'coming-of-age', 'mystery', 'fantasy', 'fantasy', 'fantasy', 'fantasy', 
                               'political satire','fantasy', 'allegory', 'tragedy', 'fantasy', 'social realism', 
                               'mystery', 'fantasy', 'historical fiction','science fiction', 'historical', 'coming-of-age']
most_ratings_slice['subgenre'] = ['fantasy', 'juvenile', 'realistic', 'detective', 'drama', 'drama', 'drama', 'epic', 
                               'allegory','drama', 'psychological', 'romance', 'young adult', 'tragedy', 
                               'detective', 'quest', 'romance','young adult', 'young adult', 'bildungsroman']
most_ratings_slice['subgenre_2'] = ['young adult', np.nan, np.nan, 'conspiracy', 'young adult', 'young adult', 'young adult', 'adventure', 
                               'dystopian','young adult', 'young adult', 'young adult', 'mythology', 'realistic', 
                               'conspiracy', 'adventure', 'adult fiction','dystopian', 'fantasy', 'juvenile']
most_ratings_slice['subgenre_3'] = [np.nan, np.nan, np.nan, 'thriller', 'mystery', 'mystery', 'mystery', 'action', 
                               'fable','mystery', np.nan, 'play', np.nan, np.nan, 
                               'thriller', 'drama', np.nan,'science fiction', 'adventure', 'comedy']
most_ratings_slice['subgenre_4'] = [np.nan, np.nan, np.nan, np.nan, 'thriller', 'thriller', 'thriller', np.nan, 
                               'science fiction','thriller', np.nan, np.nan, np.nan, np.nan, 
                               np.nan, np.nan, np.nan, np.nan, np.nan, 'autobiographical']
most_ratings_slice['subgenre_5'] = [np.nan, np.nan, np.nan, np.nan, 'bildungsroman', 'bildungsroman', 'bildungsroman', np.nan, 
                               np.nan,'bildungsroman', np.nan, np.nan, np.nan, np.nan, 
                               np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]  

book_genres = most_ratings_slice.melt(id_vars = ['title'], 
                          value_vars = ['genre', 'subgenre','subgenre_2', 'subgenre_3', 'subgenre_4', 'subgenre_5'], 
                          var_name = 'genres_subgenres', value_name = 'genre').dropna()

# %%
book_genres = book_genres.sort_values(by='genre', ascending=False)

genre_order = book_genres.genre.unique()

genre_index = book_genres.index

book_genres
# Out:
#                                                 title genres_subgenres  \
# 40                            Twilight (Twilight  #1)       subgenre_2
# 51                                   Romeo and Juliet       subgenre_2
# 37                          The Giver (The Giver  #1)         subgenre
# 38                                     The Book Thief         subgenre
# 44  Harry Potter and the Prisoner of Azkaban (Harr...       subgenre_2
# ..                                                ...              ...
# 78                                     The Book Thief       subgenre_3
# 47  The Fellowship of the Ring (The Lord of the Ri...       subgenre_2
# 55                                      The Alchemist       subgenre_2
# 56                                Memoirs of a Geisha       subgenre_2
# 67  The Fellowship of the Ring (The Lord of the Ri...       subgenre_3
#
#             genre
# 40    young adult
# 51    young adult
# 37    young adult
# 38    young adult
# 44    young adult
# ..            ...
# 78      adventure
# 47      adventure
# 55      adventure
# 56  adult fiction
# 67         action
#
# [81 rows x 3 columns]

# %%
fig = plt.figure(figsize=(12,7))
sns.countplot(data = book_genres, x = 'genre', color=sns.color_palette()[2]);
plt.xticks(rotation=90);
plt.title('Top 20 Most Rated Book, Broken Down by Genres and Subgenres')
plt.xlabel('Genre')
plt.ylabel('Number of Books');
plt.savefig('genres_subgenres_bar.png');

# %% [markdown]
# ### What is the age range for the books in the top 20 most-rated books vs the bottom 20 least-rated books?

# %%
most_ratings_slice['title']
# Out:
# 0                               Twilight (Twilight  #1)
# 1                   The Hobbit  or There and Back Again
# 2                                The Catcher in the Rye
# 3                  Angels & Demons (Robert Langdon  #1)
# 4     Harry Potter and the Prisoner of Azkaban (Harr...
# 5     Harry Potter and the Chamber of Secrets (Harry...
# 6     Harry Potter and the Order of the Phoenix (Har...
# 7     The Fellowship of the Ring (The Lord of the Ri...
# 8                                           Animal Farm
# 9     Harry Potter and the Half-Blood Prince (Harry ...
# 10                                    Lord of the Flies
# 11                                     Romeo and Juliet
# 12    The Lightning Thief (Percy Jackson and the Oly...
# 13                                      Of Mice and Men
# 14               The Da Vinci Code (Robert Langdon  #2)
# 15                                        The Alchemist
# 16                                  Memoirs of a Geisha
# 17                            The Giver (The Giver  #1)
# 18                                       The Book Thief
# 19                                         Little Women
# Name: title, dtype: object

# %% [markdown]
# ### Is there a variance between the top 20 most-rated and the top 20 most-reviewed?

# %%
most_ratings_slice['title']
# Out:
# 0                               Twilight (Twilight  #1)
# 1                   The Hobbit  or There and Back Again
# 2                                The Catcher in the Rye
# 3                  Angels & Demons (Robert Langdon  #1)
# 4     Harry Potter and the Prisoner of Azkaban (Harr...
# 5     Harry Potter and the Chamber of Secrets (Harry...
# 6     Harry Potter and the Order of the Phoenix (Har...
# 7     The Fellowship of the Ring (The Lord of the Ri...
# 8                                           Animal Farm
# 9     Harry Potter and the Half-Blood Prince (Harry ...
# 10                                    Lord of the Flies
# 11                                     Romeo and Juliet
# 12    The Lightning Thief (Percy Jackson and the Oly...
# 13                                      Of Mice and Men
# 14               The Da Vinci Code (Robert Langdon  #2)
# 15                                        The Alchemist
# 16                                  Memoirs of a Geisha
# 17                            The Giver (The Giver  #1)
# 18                                       The Book Thief
# 19                                         Little Women
# Name: title, dtype: object

# %%
most_reviews_slice = goodread_consolidated_df.sort_values(by='text_reviews_count', ascending=False).head(20)
top_20_most_ratings = most_ratings_slice['ratings_count'].sort_values(ascending=False).reset_index(drop=True)
n_ratings = most_ratings_slice.ratings_count.sum()
max_ratings_count = top_20_most_ratings[0]
max_prop_rating = max_ratings_count/n_ratings
tick_props_ratings = np.arange(0, max_prop_rating, 0.02)
tick_names_ratings = ['{:0.2f}'.format(t) for t in tick_props_ratings]

# %%
most_reviews_slice['title']
# Out:
# 8474                              Twilight (Twilight  #1)
# 4158                                       The Book Thief
# 791                             The Giver (The Giver  #1)
# 9760                                        The Alchemist
# 8786                                  Water for Elephants
# 9681    The Lightning Thief (Percy Jackson and the Oly...
# 4252                                      Eat  Pray  Love
# 9586                                     The Glass Castle
# 1098                               The Catcher in the Rye
# 9469    The Curious Incident of the Dog in the Night-Time
# 9393               The Da Vinci Code (Robert Langdon  #2)
# 9531    Harry Potter and the Prisoner of Azkaban (Harr...
# 9619    Harry Potter and the Chamber of Secrets (Harry...
# 2320                            Outlander (Outlander  #1)
# 1351                                             The Road
# 1280                  The Hobbit  or There and Back Again
# 1615                                          Animal Farm
# 9497                                   My Sister's Keeper
# 0       Harry Potter and the Order of the Phoenix (Har...
# 9365                                            Jane Eyre
# Name: title, dtype: object

# %%
most_ratings_slice.plot(x='title', y=['text_reviews_count', 'ratings_count'], kind="bar", stacked=True);
plt.title('Top 20 Most Rated Book, Broken Down by Number of Number of Ratings/Reviews');
plt.yticks(tick_props_ratings *n_ratings, tick_names_ratings);
plt.xlabel('Titles');
plt.ylabel('Proportion of Books');
plt.savefig('ratingsslice_ratings_reviews_bar.png')

# %%
top_20_most_reviews = most_reviews_slice['text_reviews_count'].sort_values(ascending=False).reset_index(drop=True)
most_reviews_slice.plot(x='title', y=['text_reviews_count', 'ratings_count'], kind="bar", stacked=True);
plt.title('Top 20 Most Reviewed Book, Broken Down by Number of Number of Ratings/Reviews');
plt.yticks(tick_props_ratings *n_ratings, tick_names_ratings);
plt.xlabel('Titles');
plt.ylabel('Proportion of Books');
plt.savefig('reviewsslice_ratings_reviews_bar.png');

# %%
most_ratings_slice
# Out:
#                                                 title               author  \
# 0                             Twilight (Twilight  #1)      Stephenie Meyer
# 1                 The Hobbit  or There and Back Again       J.R.R. Tolkien
# 2                              The Catcher in the Rye        J.D. Salinger
# 3                Angels & Demons (Robert Langdon  #1)            Dan Brown
# 4   Harry Potter and the Prisoner of Azkaban (Harr...         J.K. Rowling
# 5   Harry Potter and the Chamber of Secrets (Harry...         J.K. Rowling
# 6   Harry Potter and the Order of the Phoenix (Har...         J.K. Rowling
# 7   The Fellowship of the Ring (The Lord of the Ri...       J.R.R. Tolkien
# 8                                         Animal Farm        George Orwell
# 9   Harry Potter and the Half-Blood Prince (Harry ...         J.K. Rowling
# 10                                  Lord of the Flies      William Golding
# 11                                   Romeo and Juliet  William Shakespeare
# 12  The Lightning Thief (Percy Jackson and the Oly...         Rick Riordan
# 13                                    Of Mice and Men       John Steinbeck
# 14             The Da Vinci Code (Robert Langdon  #2)            Dan Brown
# 15                                      The Alchemist         Paulo Coelho
# 16                                Memoirs of a Geisha        Arthur Golden
# 17                          The Giver (The Giver  #1)           Lois Lowry
# 18                                     The Book Thief         Markus Zusak
# 19                                       Little Women    Louisa May Alcott
#
#     average_rating language_code            series earliest_pub_date  \
# 0             3.59           eng    Part of Series        2006-09-06
# 1             4.27           eng  In Same Universe        2002-08-15
# 2             3.80           eng        Solo Story        2001-01-30
# 3             3.89           eng    Part of Series        2003-07-28
# 4             4.56           eng    Part of Series        2004-05-01
# 5             4.42           eng    Part of Series        1999-06-02
# 6             4.49           eng    Part of Series        2004-09-01
# 7             4.36           eng    Part of Series        2003-09-05
# 8             3.93           eng        Solo Story        2003-05-06
# 9             4.57           eng    Part of Series        2006-06-23
# 10            3.68           eng        Solo Story        1959-07-01
# 11            3.74           eng        Solo Story        1997-10-23
# 12            4.25           eng    Part of Series        2006-01-06
# 13            3.87           eng        Solo Story        2002-01-08
# 14            3.84           eng    Part of Series        2003-03-18
# 15            3.86           eng        Solo Story        1993-05-01
# 16            4.11           eng        Solo Story        1998-06-04
# 17            4.13           eng    Part of Series        2006-01-24
# 18            4.37           eng        Solo Story        2006-03-14
# 19            4.07           eng  In Same Universe        2000-01-01
#
#    latest_pub_date  ratings_count  text_reviews_count     gender skin_color  \
# 0       2006-09-06        4597666               94265  cis woman      white
# 1       2002-08-15        2530894               32871    cis man      white
# 2       2001-01-30        2457092               43499    cis man      white
# 3       2006-04-01        2425666               22076    cis man      white
# 4       2008-07-01        2342726               36465  cis woman      white
# 5       2003-11-01        2300296               34936  cis woman      white
# 6       2004-09-01        2153167               29221  cis woman      white
# 7       2004-06-01        2130267               13791    cis man      white
# 8       2003-05-06        2111750               29677    cis man      white
# 9       2006-09-16        2096903               27669  cis woman      white
# 10      2005-10-11        2037566               26352    cis man      white
# 11      2012-07-15        1895075               14710    cis man      white
# 12      2006-03-01        1766864               47985    cis man      white
# 13      2002-01-08        1755253               25554    cis man      white
# 14      2006-03-28        1686222               36634    cis man      white
# 15      2006-05-02        1632141               55919    cis man      white
# 16      2005-12-01        1587760               23725    cis man      white
# 17      2006-01-24        1585589               56604  cis woman      white
# 18      2006-03-14        1516367               86881    cis man      white
# 19      2004-04-06        1480438               18521  cis woman      white
#
#    category               genre       subgenre     subgenre_2  \
# 0   fiction             romance        fantasy    young adult
# 1   fiction             fantasy       juvenile            NaN
# 2   fiction       coming-of-age      realistic            NaN
# 3   fiction             mystery      detective     conspiracy
# 4   fiction             fantasy          drama    young adult
# 5   fiction             fantasy          drama    young adult
# 6   fiction             fantasy          drama    young adult
# 7   fiction             fantasy           epic      adventure
# 8   fiction    political satire       allegory      dystopian
# 9   fiction             fantasy          drama    young adult
# 10  fiction            allegory  psychological    young adult
# 11  fiction             tragedy        romance    young adult
# 12  fiction             fantasy    young adult      mythology
# 13  fiction      social realism        tragedy      realistic
# 14  fiction             mystery      detective     conspiracy
# 15  fiction             fantasy          quest      adventure
# 16  fiction  historical fiction        romance  adult fiction
# 17  fiction     science fiction    young adult      dystopian
# 18  fiction          historical    young adult        fantasy
# 19  fiction       coming-of-age  bildungsroman       juvenile
#
#          subgenre_3        subgenre_4     subgenre_5
# 0               NaN               NaN            NaN
# 1               NaN               NaN            NaN
# 2               NaN               NaN            NaN
# 3          thriller               NaN            NaN
# 4           mystery          thriller  bildungsroman
# 5           mystery          thriller  bildungsroman
# 6           mystery          thriller  bildungsroman
# 7            action               NaN            NaN
# 8             fable   science fiction            NaN
# 9           mystery          thriller  bildungsroman
# 10              NaN               NaN            NaN
# 11             play               NaN            NaN
# 12              NaN               NaN            NaN
# 13              NaN               NaN            NaN
# 14         thriller               NaN            NaN
# 15            drama               NaN            NaN
# 16              NaN               NaN            NaN
# 17  science fiction               NaN            NaN
# 18        adventure               NaN            NaN
# 19           comedy  autobiographical            NaN

# %%
most_reviews_slice
# Out:
#                                                   title             author  \
# 8474                            Twilight (Twilight  #1)    Stephenie Meyer
# 4158                                     The Book Thief       Markus Zusak
# 791                           The Giver (The Giver  #1)         Lois Lowry
# 9760                                      The Alchemist       Paulo Coelho
# 8786                                Water for Elephants         Sara Gruen
# 9681  The Lightning Thief (Percy Jackson and the Oly...       Rick Riordan
# 4252                                    Eat  Pray  Love  Elizabeth Gilbert
# 9586                                   The Glass Castle    Jeannette Walls
# 1098                             The Catcher in the Rye      J.D. Salinger
# 9469  The Curious Incident of the Dog in the Night-Time        Mark Haddon
# 9393             The Da Vinci Code (Robert Langdon  #2)          Dan Brown
# 9531  Harry Potter and the Prisoner of Azkaban (Harr...       J.K. Rowling
# 9619  Harry Potter and the Chamber of Secrets (Harry...       J.K. Rowling
# 2320                          Outlander (Outlander  #1)     Diana Gabaldon
# 1351                                           The Road    Cormac McCarthy
# 1280                The Hobbit  or There and Back Again     J.R.R. Tolkien
# 1615                                        Animal Farm      George Orwell
# 9497                                 My Sister's Keeper   Mavis Applewater
# 0     Harry Potter and the Order of the Phoenix (Har...       J.K. Rowling
# 9365                                          Jane Eyre   Charlotte Brontë
#
#       average_rating language_code  series earliest_pub_date latest_pub_date  \
# 8474            3.59           eng    True        2006-09-06      2006-09-06
# 4158            4.37           eng   False        2006-03-14      2006-03-14
# 791             4.13           eng    True        2006-01-24      2006-01-24
# 9760            3.86           eng   False        1993-05-01      2006-05-02
# 8786            4.09           eng   False        2007-05-01      2007-05-01
# 9681            4.25           eng    True        2006-01-06      2006-03-01
# 4252            3.55           eng   False        2007-02-01      2007-02-01
# 9586            4.27           eng   False        2005-11-01      2006-01-17
# 1098            3.80           eng   False        2001-01-30      2001-01-30
# 9469            3.88           eng   False        2004-04-15      2006-12-01
# 9393            3.84           eng    True        2003-03-18      2006-03-28
# 9531            4.56           eng    True        2004-05-01      2008-07-01
# 9619            4.42           eng    True        1999-06-02      2003-11-01
# 2320            4.23           eng    True        2005-07-26      2005-07-26
# 1351            3.97           eng   False        2006-09-26      2006-09-26
# 1280            4.27           eng   False        2002-08-15      2002-08-15
# 1615            3.93           eng   False        2003-05-06      2003-05-06
# 9497            3.86           eng   False        2004-03-09      2005-02-01
# 0               4.49           eng    True        2004-09-01      2004-09-01
# 9365            4.12           eng   False        1997-06-17      2006-06-29
#
#       ratings_count  text_reviews_count
# 8474        4597666               94265
# 4158        1516367               86881
# 791         1585589               56604
# 9760        1632141               55919
# 8786        1260027               52759
# 9681        1766864               47985
# 4252        1362264               47620
# 9586         808670               46182
# 1098        2457092               43499
# 9469        1071510               37262
# 9393        1686222               36634
# 9531        2342726               36465
# 9619        2300296               34936
# 2320         673350               34690
# 1351         606433               34301
# 1280        2530894               32871
# 1615        2111750               29677
# 9497         986800               29654
# 0           2153167               29221
# 9365        1420001               28972

# %% [markdown]
# ### Other questions to look into:
# #### What is the gender breakdown in the top 20 most-rated books vs the bottom 20 least-rated books?
# #### What is the skin color breakdown in the top 20 most-rated books vs the bottom 20 least-rated books?
# #### What is the fiction/non-fiction breakdown in the top 20 most-rated books vs the bottom 20 least-rated books?
# #### What is the series/not-a-series breakdown in the top 20 most-rated books vs the bottom 20 least-rated books?
# #### What is the relationship between book length and being at either extreme in the most- or least-rated books?
#
# #### What gender is in the top 20 most-reviewed books vs the bottom 20 least-reviewed books?
# #### What is the skin color breakdown in the top 20 most-reviewed books vs the bottom 20 least-reviewed books?
# #### What is the fiction/non-fiction breakdown in the top 20 most-reviewed books vs the bottom 20 least-reviewed books?
# #### What is the series/not-a-series breakdown in the top 20 most-reviewed books vs the bottom 20 least-reviewed books?
# #### What is the relationship between book length and being at either extreme in the most- or least-rated books?
